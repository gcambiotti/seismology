# %% [markdown]
# (chap-L1)=
# # Seismic catalogs and networks
#
#
# ```{contents} Sections
# :local:
# :depth: 2
# ```

# %% [markdown]
# ```{div} full-width
# With this lecture we will learn how download earthquake catalagos and seismic networks from the main data center of the world. As case study, we will choose the Istituto Nazionale di Geofisica e Vulcanologia (INGV) as provider and we will focus on the 2016-2017 Amatrice-Norcia-Visso seismic sequences and, in particular, on the first main shock: the 24 August 2016 M=6 Accumuli earthquake.
#
# In this perspective, let us import the main python libraries
# ```

# %%
# %matplotlib widget
import lab
import numpy as np
import matplotlib.pyplot as plt

# %%
from myst_nb import glue
# %matplotlib inline
np.set_printoptions(precision=3,suppress=False)
import warnings
warnings.filterwarnings("ignore")

# %%
directory="Amatrice-Norcia-Visso/"
glue("directory","Amatrice-Norcia-Visso")
# Out:
# 'Amatrice-Norcia-Visso'

# %% [markdown]
# ```{div} full-width
# and make the directory {glue:}`directory` where we will save the data that we are going to download
# ```

# %%
import os

directory="Amatrice-Norcia-Visso/"
if not os.path.exists(directory):
    os.mkdir(directory)

# %% [markdown]
# ## Dates

# %% [markdown]
# ```{div} full-width
# In order to specify the time periods on which we are interested in and for which we want to download data, we shall use the class `UTCDateTime` from the `obspy` module
# ```

# %%
from obspy import UTCDateTime

# %% [markdown]
# ```{div} full-width
# Just because the Amatrice-Norcia-Visso seismic sequence spanned almost two years, from August 2016 to January 2017, we define as start time the 1-th January 2016 and end time the 1-th January 2018
# ```

# %%
starttime = UTCDateTime(2016,1,1)
endtime = UTCDateTime(2018,1,1)
print("starttime:               ",starttime)
print("endtime:                 ",endtime)
# Out:
# starttime:                2016-01-01T00:00:00.000000Z
# endtime:                  2018-01-01T00:00:00.000000Z

# %% [markdown]
# ```{div} full-width
# We note that we perform some basic operations with `UTCDateTime` objects, as for instance,
# ```

# %%
newtime = starttime + 3*24*3600 + 3600+120 + 5.2
print("newtime:           ",newtime)
print("endtime-starttime: ",(endtime-starttime)/3600/24,"days")
# Out:
# newtime:            2016-01-04T01:02:05.200000Z
# endtime-starttime:  731.0 days

# %% [markdown]
# ## Catalogs

# %% [markdown]
# ```{div} full-width
#
# Let us import the class `Client` from `obspy` and set the Istituto Nazionale di Geofisica e Vulcanologia (INGV) as provider
#
# ```

# %%
from obspy.clients.fdsn import Client

client = Client("INGV")
print(client)
# Out:
# FDSN Webservice Client (base url: http://webservices.ingv.it)
# Available Services: 'dataselect' (v1.1.0), 'event' (v1.52.9), 'station' (v1.1.54), 'available_event_catalogs', 'available_event_contributors', 'eida-auth'
#
# Use e.g. client.help('dataselect') for the
# parameter description of the individual services
# or client.help() for parameter description of
# all webservices.

# %% [markdown]
# ```{div} full-width
# Thanks to the method `client.get_events`, we will download  the earthquakes occurred in Central Italy during the 2016 and 2017 of magnitude M$\ge$5
# ```

# %%
help(client.get_events)
# Out:
# Help on method get_events in module obspy.clients.fdsn.client:
#
# get_events(starttime=None, endtime=None, minlatitude=None, maxlatitude=None, minlongitude=None, maxlongitude=None, latitude=None, longitude=None, minradius=None, maxradius=None, mindepth=None, maxdepth=None, minmagnitude=None, maxmagnitude=None, magnitudetype=None, eventtype=None, includeallorigins=None, includeallmagnitudes=None, includearrivals=None, eventid=None, limit=None, offset=None, orderby=None, catalog=None, contributor=None, updatedafter=None, filename=None, **kwargs) method of obspy.clients.fdsn.client.Client instance
#     Query the event service of the client.
#
#     >>> client = Client("IRIS")
#     >>> cat = client.get_events(eventid=609301)
#     >>> print(cat)
#     1 Event(s) in Catalog:
#     1997-10-14T09:53:11.070000Z | -22.145, -176.720 | 7.8 ...
#
#     The return value is a :class:`~obspy.core.event.Catalog` object
#     which can contain any number of events.
#
#     >>> t1 = UTCDateTime("2001-01-07T00:00:00")
#     >>> t2 = UTCDateTime("2001-01-07T03:00:00")
#     >>> cat = client.get_events(starttime=t1, endtime=t2, minmagnitude=4,
#     ...                         catalog="ISC")
#     >>> print(cat)
#     3 Event(s) in Catalog:
#     2001-01-07T02:55:59.290000Z |  +9.801,  +76.548 | 4.9 ...
#     2001-01-07T02:35:35.170000Z | -21.291,  -68.308 | 4.4 ...
#     2001-01-07T00:09:25.630000Z | +22.946, -107.011 | 4.0 ...
#
#     :type starttime: :class:`~obspy.core.utcdatetime.UTCDateTime`, optional
#     :param starttime: Limit to events on or after the specified start time.
#     :type endtime: :class:`~obspy.core.utcdatetime.UTCDateTime`, optional
#     :param endtime: Limit to events on or before the specified end time.
#     :type minlatitude: float, optional
#     :param minlatitude: Limit to events with a latitude larger than the
#         specified minimum.
#     :type maxlatitude: float, optional
#     :param maxlatitude: Limit to events with a latitude smaller than the
#         specified maximum.
#     :type minlongitude: float, optional
#     :param minlongitude: Limit to events with a longitude larger than the
#         specified minimum.
#     :type maxlongitude: float, optional
#     :param maxlongitude: Limit to events with a longitude smaller than the
#         specified maximum.
#     :type latitude: float, optional
#     :param latitude: Specify the latitude to be used for a radius search.
#     :type longitude: float, optional
#     :param longitude: Specify the longitude to be used for a radius
#         search.
#     :type minradius: float, optional
#     :param minradius: Limit to events within the specified minimum number
#         of degrees from the geographic point defined by the latitude and
#         longitude parameters.
#     :type maxradius: float, optional
#     :param maxradius: Limit to events within the specified maximum number
#         of degrees from the geographic point defined by the latitude and
#         longitude parameters.
#     :type mindepth: float, optional
#     :param mindepth: Limit to events with depth, in kilometers, larger than
#         the specified minimum.
#     :type maxdepth: float, optional
#     :param maxdepth: Limit to events with depth, in kilometers, smaller
#         than the specified maximum.
#     :type minmagnitude: float, optional
#     :param minmagnitude: Limit to events with a magnitude larger than the
#         specified minimum.
#     :type maxmagnitude: float, optional
#     :param maxmagnitude: Limit to events with a magnitude smaller than the
#         specified maximum.
#     :type magnitudetype: str, optional
#     :param magnitudetype: Specify a magnitude type to use for testing the
#         minimum and maximum limits.
#     :type eventtype: str, optional
#     :param eventtype: Limit to events with a specified event type.
#         Multiple types are comma-separated (e.g.,
#         ``"earthquake,quarry blast"``). Allowed values are from QuakeML.
#         See :const:`obspy.core.event.header.EventType` for a list of
#         allowed event types.
#     :type includeallorigins: bool, optional
#     :param includeallorigins: Specify if all origins for the event should
#         be included, default is data center dependent but is suggested to
#         be the preferred origin only.
#     :type includeallmagnitudes: bool, optional
#     :param includeallmagnitudes: Specify if all magnitudes for the event
#         should be included, default is data center dependent but is
#         suggested to be the preferred magnitude only.
#     :type includearrivals: bool, optional
#     :param includearrivals: Specify if phase arrivals should be included.
#     :type eventid: str or int, optional
#     :param eventid: Select a specific event by ID; event identifiers are
#         data center specific (String or Integer).
#     :type limit: int, optional
#     :param limit: Limit the results to the specified number of events.
#     :type offset: int, optional
#     :param offset: Return results starting at the event count specified,
#         starting at 1.
#     :type orderby: str, optional
#     :param orderby: Order the result by time or magnitude with the
#         following possibilities:
#
#         * time: order by origin descending time
#         * time-asc: order by origin ascending time
#         * magnitude: order by descending magnitude
#         * magnitude-asc: order by ascending magnitude
#
#     :type catalog: str, optional
#     :param catalog: Limit to events from a specified catalog
#     :type contributor: str, optional
#     :param contributor: Limit to events contributed by a specified
#         contributor.
#     :type updatedafter: :class:`~obspy.core.utcdatetime.UTCDateTime`,
#         optional
#     :param updatedafter: Limit to events updated after the specified time.
#     :type filename: str or file
#     :param filename: If given, the downloaded data will be saved there
#         instead of being parsed to an ObsPy object. Thus it will contain
#         the raw data from the webservices.
#
#
#     Any additional keyword arguments will be passed to the webservice as
#     additional arguments. If you pass one of the default parameters and the
#     webservice does not support it, a warning will be issued. Passing any
#     non-default parameters that the webservice does not support will raise
#     an error.

# %% [markdown]
# ```{div} full-width
#
# In this perspective, let us define the `file` where we will save the downloaded data and define the geographic `circle` in which we are interested in as a dictionary containing the longitude and latitude of its centre (13°,42.5°) and its radius (2°, in degrees)
# ```

# %%
file = directory+"Seismic_Sequence_M5.xml"
circle = dict(maxradius=2,longitude=13,latitude=42.5)

# %% [markdown]
# ```{div} full-width
# and use them as arguments of the method `client.get_events` along with the already defined `starttime` and `endtime`
# ```

# %%
client.get_events(starttime=starttime, endtime=endtime, minmagnitude=5, **circle, filename=file)

# %% [markdown]
# ```{div} full-width
# Afterwards, we can read the `file` and get the downloaded `Catalog` object as follows
# ```

# %%
from obspy.core.event import read_events
catalog = read_events(file)
print(catalog)
# Out:
# 9 Event(s) in Catalog:
# 2017-01-18T13:33:36.740000Z | +42.473,  +13.275 | 5.0  Mw | manual
# 2017-01-18T10:25:23.730000Z | +42.503,  +13.277 | 5.4  Mw | manual
# 2017-01-18T10:14:09.900000Z | +42.531,  +13.284 | 5.5  Mw | manual
# 2017-01-18T09:25:40.390000Z | +42.545,  +13.277 | 5.1  Mw | manual
# 2016-10-30T06:40:17.320000Z | +42.830,  +13.109 | 6.5  Mw | manual
# 2016-10-26T19:18:07.420000Z | +42.905,  +13.090 | 5.9  Mw | manual
# 2016-10-26T17:10:36.980000Z | +42.875,  +13.124 | 5.4  Mw | manual
# 2016-08-24T02:33:28.890000Z | +42.792,  +13.151 | 5.4  Mw | manual
# 2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual

# %%
glue("numevents",len(catalog))
# Out:
# 9

# %% [markdown]
# ```{div} full-width
# As we can notice, the `catalog` contains {glue:}`numevents` earthquakes ordered by descending dates. In order to have a first understanding of what we have just downloaded, let us plot it using the the method `catalog.plot` along with the function `lab.setup_map` described in {numref}`Lecture %s Geographic maps <chap-geographic-maps>`
# ```

# %%
import lab 
title = "2016-2017 Amatrice-Norcia-Visso seismic sequence (M$\geq$5)"
fig = lab.setup_map(circle=circle,color="red")
fig = catalog.plot(fig=fig,title=title)

# %% [markdown]
# Here instead we zoom in the cluster of earthquakes

# %%
extent = [12.5,14,42.4,43]
fig = lab.setup_map(extent=extent)
fig = catalog.plot(fig=fig,title=title)

# %% [markdown]
# ### The 2016-08-24 M=6 Accumuli earthquake

# %% [markdown]
# ```{div} full-width
# The `catalog` can be seen as a list of events, each of which contains information about an earthquake
# ```

# %%
for ke,event in enumerate(catalog):
    print("\n\n{0:4d}-th EVENT:\n".format(ke))
    print(event)
# Out:
#    0-th EVENT:
#
# Event:	2017-01-18T13:33:36.740000Z | +42.473,  +13.275 | 5.0  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=12707401")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2017, 1, 18, 13, 33, 57))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=39297271")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=40543881")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=10661")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    1-th EVENT:
#
# Event:	2017-01-18T10:25:23.730000Z | +42.503,  +13.277 | 5.4  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=12698071")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2017, 1, 18, 10, 25, 41))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=39298641")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=40524141")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=10581")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    2-th EVENT:
#
# Event:	2017-01-18T10:14:09.900000Z | +42.531,  +13.284 | 5.5  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=12697591")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2017, 1, 18, 10, 14, 29))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=39304051")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=40521301")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=10561")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    3-th EVENT:
#
# Event:	2017-01-18T09:25:40.390000Z | +42.545,  +13.277 | 5.1  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=12695491")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2017, 1, 18, 9, 25, 59))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=39298651")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=40513101")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=10541")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    4-th EVENT:
#
# Event:	2016-10-30T06:40:17.320000Z | +42.830,  +13.109 | 6.5  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=8863681")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 10, 30, 6, 40, 33))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=57734241")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=32953271")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=8381")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    5-th EVENT:
#
# Event:	2016-10-26T19:18:07.420000Z | +42.905,  +13.090 | 5.9  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=8669321")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 10, 26, 19, 18, 17))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=57841241")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=32553761")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=8101")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    6-th EVENT:
#
# Event:	2016-10-26T17:10:36.980000Z | +42.875,  +13.124 | 5.4  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=8663031")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 10, 26, 17, 10, 53))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=54744211")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=32524401")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=8061")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    7-th EVENT:
#
# Event:	2016-08-24T02:33:28.890000Z | +42.792,  +13.151 | 5.4  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=7076161")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 2, 33, 48))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27165431")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31505421")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7641")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 2 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements
#
#
#    8-th EVENT:
#
# Event:	2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=7073641")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 52))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31549261")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7631")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 2 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements

# %% [markdown]
# ```{div} full-width
# Let us select the last element of this list, which is the `Event` object describing the early earthquake of the seismic sequence
# ```

# %%
event = catalog[-1]
print(event)
# Out:
# Event:	2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=7073641")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 52))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31549261")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7631")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	             focal_mechanisms: 2 Elements
# 	                      origins: 1 Elements
# 	                   magnitudes: 1 Elements

# %% [markdown]
# ```{div} full-width
# From this `Event` object, we can get its description
# ```

# %%
for event_description in event.event_descriptions:
    print(event_description.text)
# Out:
# 1 km W Accumoli (RI)

# %% [markdown]
# ```{div} full-width
# and its preferred origin, magnitude and focal mechanism
# ```

# %%
origin = event.preferred_origin()
print("PREFERRED ORIGIN:\n\n",origin)
# Out:
# PREFERRED ORIGIN:
#
#  Origin
# 	        resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	               time: UTCDateTime(2016, 8, 24, 1, 36, 32) [uncertainty=0.03]
# 	          longitude: 13.2335 [uncertainty=0.0024]
# 	           latitude: 42.6983 [uncertainty=0.0009]
# 	              depth: 8100.0 [uncertainty=200.0]
# 	         depth_type: 'from location'
# 	          method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1")
# 	     earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	            quality: OriginQuality(associated_phase_count=289, used_phase_count=289, associated_station_count=280, used_station_count=280, standard_error=0.11, azimuthal_gap=28.0, minimum_distance=0.10072, maximum_distance=5.38694)
# 	        origin_type: 'hypocenter'
# 	 origin_uncertainty: OriginUncertainty(horizontal_uncertainty=150.0, min_horizontal_uncertainty=132.0, max_horizontal_uncertainty=154.0, azimuth_max_horizontal_uncertainty=76.0, preferred_description='uncertainty ellipse', confidence_level=68.0)
# 	    evaluation_mode: 'manual'
# 	  evaluation_status: 'reviewed'
# 	      creation_info: CreationInfo(agency_id='INGV', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 31, 6, 40, 9), version='1000')

# %%
magnitude = event.preferred_magnitude()
print("PREFERRED MAGNITUDE:\n\n",magnitude)
# Out:
# PREFERRED MAGNITUDE:
#
#  Magnitude
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31549261")
# 	            mag: 6.0
# 	 magnitude_type: 'Mw'
# 	      origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=29594981")
# 	      method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodId=171")
# 	  creation_info: CreationInfo(agency_id='INGV', author='TDMT-INGV Revised', creation_time=UTCDateTime(2016, 9, 27, 11, 45, 32))

# %%
focal_mechanism = event.preferred_focal_mechanism()
print("PREFERRED FOCAL MECHANISM:\n\n",focal_mechanism)
# Out:
# PREFERRED FOCAL MECHANISM:
#
#  FocalMechanism
# 	          resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7631")
# 	 triggering_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=26962871")
# 	         nodal_planes: NodalPlanes(nodal_plane_1=NodalPlane(strike=155.0, dip=49.0, rake=-87.0), nodal_plane_2=NodalPlane(strike=331.0, dip=41.0, rake=-93.0))
# 	      evaluation_mode: 'manual'
# 	    evaluation_status: 'reviewed'
# 	        moment_tensor: MomentTensor(resource_id=ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=7631"), derived_origin_id=ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=29420591"), moment_magnitude_id=ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31363711"), scalar_moment=1.06622e+18, tensor=Tensor(m_rr=-1.06092883e+18, m_tt=2.2822264e+17, m_pp=8.3270619e+17, m_rt=-3.104816e+16, m_rp=1.4210325999999998e+17, m_tp=-4.2453358e+17), variance_reduction=55.02, double_couple=0.98, clvd=0.02, iso=0.0, creation_info=CreationInfo(agency_id='INGV', author='Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT', creation_time=UTCDateTime(2016, 9, 23, 11, 19, 11)))
# 	        creation_info: CreationInfo(agency_id='INGV', author='Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT', creation_time=UTCDateTime(2016, 9, 23, 11, 19, 11))

# %% [markdown]
# ```{div} full-width
# Here a beachball plot of the focal mechanism, which show that we are considering a normal earthquake
# ```

# %%
nodal_plane_1 = list(focal_mechanism.nodal_planes.get("nodal_plane_1").values())[::2]
print("nodal plane 1:",nodal_plane_1)

from obspy.imaging.beachball import beachball
fig = plt.figure(tight_layout=True)
fig = beachball(nodal_plane_1,fig=fig)
# Out:
# nodal plane 1: [155.0, 49.0, -87.0]

# %% [markdown]
# #### Event id and additional information

# %% [markdown]
# ```{div} full-width
# Let us now obtain the event id assigned to the M=6 Accumuli earthquake
# ```

# %%
eventid = str(event.resource_id).split("=")[-1]
print("EVENTID:",eventid)
# Out:
# EVENTID: 7073641

# %% [markdown]
# ```{div} full-width
# and download a catalog with just this earthquake but with more information about it than before
# ```

# %%
file = directory+eventid+"_Accumuli.xml"
client.get_events(eventid=eventid,includeallorigins=True,includeallmagnitudes=True,includearrivals=True,filename=file)
catalog = read_events(file)
print(catalog)
# Out:
# 1 Event(s) in Catalog:
# 2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual

# %%
event = catalog[0]
glue("numorigins",len(event.origins))
glue("nummagnitudes",len(event.magnitudes))
# Out:
# 8
# 8

# %% [markdown]
# ```{div} full-width
# Selecting the only event in the catalog, we can now see that there are {glue:}`numorigins` origins and {glue:}`nummagnitudes` magnitudes (instead of just one) and also a new field named `picks`. We will discuss this latter field in {numref}`Lecture %s <chap-L3>` {ref}`chap-L3`
# ```

# %%
event = catalog[0]
print(event)
# Out:
# Event:	2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=7073641")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 52))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31549261")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7631")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	                        picks: 699 Elements
# 	             focal_mechanisms: 2 Elements
# 	                      origins: 8 Elements
# 	                   magnitudes: 8 Elements

# %% [markdown]
# ```{div} full-width
# In particular, we can notice that the {glue:}`numorigins` origins have different authors and values
# ```

# %%
print("{0:40}  {1:>7}  {2:>7} {3:>6}  {4:>10}\n".format("author","lon","lat","dep","origin_id"))
for origin in event.origins:
    author    = origin.creation_info.author
    origin_id = origin.resource_id.id.split("=")[1]
    lon, lat  = origin.longitude, origin.latitude
    dep = origin.depth/1e3
    print("{0:40}  {1:>7.4f}  {2:>7.4f} {3:>6.2f}  {4:>10}".format(author,lon,lat,dep,origin_id))
# Out:
# author                                        lon      lat    dep   origin_id
#
# tdmt_reviewer                             13.2232  42.7063   5.00    26962871
# BULLETIN-INGV                             13.2335  42.6983   8.10    27629391
# tdmt_reviewer                             13.2232  42.7063   5.00    29420591
# tdmt_reviewer                             13.2232  42.7063   5.00    29594981
# hew1_mole#MOD_EQASSEMBLE                  13.1815  42.6883   1.31    26951261
# SURVEY-INGV                               13.2232  42.7063   4.20    26952071
# hew1_mole#MOD_EQASSEMBLE                  13.2563  42.6943  21.92    26951141
# hew1_mole#MOD_EQASSEMBLE                  13.2190  42.6792  16.17    26951211

# %% [markdown]
# ```{div} full-width
# as well as the  the {glue:}`nummagnitudes` magnitudes
# ```

# %%
print("{0:40}  {1:>4}  {2:>4}   {3:>10}  {4:>10} {5:>10}\n".format("Author","mag","std","type","mag_id","origin_id"))
for magnitude in event.magnitudes:
    
    author    = magnitude.creation_info.author
    
    mag_id = magnitude.resource_id.id.split("=")[1]
    origin_id = magnitude.origin_id.id.split("=")[1]
    
    mag = magnitude.mag
    mag_type = magnitude.magnitude_type
    std = magnitude.mag_errors.uncertainty
    
    if std is None: std=0
    
    print("{0:40}  {1:>4.1f}  {2:>4.1f}  {3:>5}  {4:>5}  {5:>10}".format(author,mag,std,mag_type,mag_id,origin_id))
# Out:
# Author                                     mag   std         type      mag_id  origin_id
#
# TDMT-INGV Revised                          6.0   0.0     Mw  31549261    29594981
# TDMT-INGV Revised                          6.0   0.0     Mw  29064551    26962871
# TDMT-INGV Revised                          6.0   0.0     Mw  31363711    29420591
# Sala Sismica INGV-Roma                     6.0   0.3     ML  29053271    26952071
# Bollettino Sismico Italiano INGV           6.0   0.3     ML  29758611    27629391
# Sistema Automatico Earthworm-1             6.1   0.7     ML  29052291    26951211
# Sistema Automatico Earthworm-1             5.8   0.5     ML  29052251    26951141
# Sistema Automatico Earthworm-1             6.0   0.6     ML  29052391    26951261

# %% [markdown]
# ```{div} full-width
# In the following, we will attempt to reproduce the results from the Bollettino Sismico Italiano by the INGV estimating the hypocenter location and origin time, as well as the local magnitude. We thus select the preferred origin that is that of Bollettino Sismico Italiano
# ```

# %%
origin = event.preferred_origin()
print("\nPREFERRED ORIGIN:\n\n",origin)
# Out:
# PREFERRED ORIGIN:
#
#  Origin
# 	        resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	               time: UTCDateTime(2016, 8, 24, 1, 36, 32) [uncertainty=0.03]
# 	          longitude: 13.2335 [uncertainty=0.0024]
# 	           latitude: 42.6983 [uncertainty=0.0009]
# 	              depth: 8100.0 [uncertainty=200.0]
# 	         depth_type: 'from location'
# 	          method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1")
# 	     earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	            quality: OriginQuality(associated_phase_count=289, used_phase_count=289, associated_station_count=280, used_station_count=280, standard_error=0.11, azimuthal_gap=28.0, minimum_distance=0.10072, maximum_distance=5.38694)
# 	        origin_type: 'hypocenter'
# 	 origin_uncertainty: OriginUncertainty(horizontal_uncertainty=150.0, min_horizontal_uncertainty=132.0, max_horizontal_uncertainty=154.0, azimuth_max_horizontal_uncertainty=76.0, preferred_description='uncertainty ellipse', confidence_level=68.0)
# 	    evaluation_mode: 'manual'
# 	  evaluation_status: 'reviewed'
# 	      creation_info: CreationInfo(agency_id='INGV', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 31, 6, 40, 9), version='1000')
# 	               ---------
# 	           arrivals: 289 Elements

# %% [markdown]
# ```{div} full-width
# and look for the associated magnitude by comparing the origin and magnitude identifiers
# ```

# %%
for magnitude in event.magnitudes:
    if magnitude.origin_id == origin.resource_id: break
print("\nASSOCIATED MAGNITUDE:\n\n",magnitude)
# Out:
# ASSOCIATED MAGNITUDE:
#
#  Magnitude
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=29758611")
# 	            mag: 6.0 [uncertainty=0.3]
# 	 magnitude_type: 'ML'
# 	      origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	      method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1")
# 	  station_count: 159
# 	  creation_info: CreationInfo(agency_id='INGV', author='Bollettino Sismico Italiano INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))

# %% [markdown]
# ```{div} full-width
# We note, indeed, that the origin identifier of the selected magnitude is the same identifier of the prefered origin. We also note that, now, the preferred origin has a new field named `arrivals`. As for the field `picks`, we will discuss this latter field in {numref}`Lecture %s <chap-L3>` {ref}`chap-L3`
# ```

# %% [markdown]
# ## Inventory

# %% [markdown]
# ```{div} full-width
# Let us now download all the seismic stations from all the networks managed to some extent by the INGV thank to the method `client.get_stations`. In particular, we will query the data center for all the seismic stations that have operated between the 2016 and 2017 and the information about their response functions, and we will save these informations on a file
# ```

# %%
file = directory+"Inventory.xml"
client.get_stations(level="response",starttime=starttime,endtime=endtime,filename=file)

# %% [markdown]
# ```{div} full-width
# that we can read afterwards as follows
# ```

# %%
from obspy.core.inventory import read_inventory
inventory = read_inventory(file)

# %% [markdown]
# ```{div} full-width
# All these information are stored in an `Inventory` object.  In order to have a first understanding of what we have just downloaded, let us plot it using the the method `inventory.plot` along with the function `lab.setup_map`
# ```

# %%
fig = lab.setup_map()
fig = inventory.plot(fig=fig,marker=".",size=10,color="red",label=False)

# %% [markdown]
# ```{div} full-width
# Almost all stations are located in Italy, but for a few seismic station in Europe, Turkey and Marocco and one in Antartica. Here, the same plot but zoomed in Italy
# ```

# %%
extent = [6.5,19,36,47.5]
fig = lab.setup_map(extent=extent)
fig = inventory.plot(fig=fig,marker="v",size=10,color="red",label=False)

# %% [markdown]
# ```{div} full-width
# In order to understand what we have just downloaded, let us print the `inventory`
# ```

# %%
print(inventory)
# Out:
# Inventory created at 2023-02-22T05:57:32.927000Z
# 	Created by: INGV-ONT WEB SERVICE: fdsnws-station | version: 1.1.54
# 		    /exist/apps/fdsn-station/fdsnws/station/1/query?starttime=2016-01-...
# 	Sending institution: eXistDB (INGV-ONT)
# 	Contains:
# 		Networks (18):
# 			3A, 5J, 7C, AC, BA, GU, IV, IX, MN, NI, OT, OX, RF, SI, ST, TV, XO
# 			Z3
# 		Stations (666):
# 			3A.MZ01 (Saletta - INGV/IMAA-CNR)
# 			3A.MZ02 (Casale - INGV)
# 			3A.MZ03 (Collalto - INGV)
# 			3A.MZ04 (Cossito - INGV/IMAA-CNR)
# 			3A.MZ05 (San Tomasso - INGV)
# 			3A.MZ06 (San Lorenzo Flaviano - INGV)
# 			3A.MZ07 (Sant`Angelo - INGV)
# 			3A.MZ08 (Amatrice/RAN - INGV)
# 			3A.MZ09 (Sommati - INGV)
# 			3A.MZ095 (Colle Spada - ENEA)
# 			3A.MZ096 (Colle Posta - ENEA)
# 			3A.MZ097 (Cassino - ENEA)
# 			3A.MZ098 (Grisciano 1 - ENEA)
# 			3A.MZ099 (Terracino - ENEA)
# 			3A.MZ10 (Amatrice/San Cipriano - INGV)
# 			3A.MZ100 (Fonte del Campo - ENEA)
# 			3A.MZ101 (Illica - ENEA)
# 			3A.MZ102 (Accumoli Madonna delle Coste - ENEA)
# 			3A.MZ103 (Accumoli campo sportivo - ENEA)
# 			3A.MZ104 (Tino - ENEA)
# 			3A.MZ105 (San Giovanni - ENEA)
# 			3A.MZ11 (bedrock nord Sant`Angelo - INGV)
# 			3A.MZ12 (Amatrice giardino - INGV)
# 			3A.MZ13 (Cornillo Vecchio - INGV)
# 			3A.MZ14 (Capricchia bedrock - INGV)
# 			3A.MZ15 (Torrita terrazzo basso - INGV)
# 			3A.MZ16 (Torrita terrazzo alto - INGV)
# 			3A.MZ17 (Scai Agriturismo Narcisi - INGV)
# 			3A.MZ18 (Scai alta - INGV)
# 			3A.MZ19 (Pasciano cimitero - INGV)
# 			3A.MZ20 (Collemoresco - INGV)
# 			3A.MZ21 (Poggio Vitellino - INGV)
# 			3A.MZ22 (Petrana - INGV)
# 			3A.MZ23 (Faizzone - INGV)
# 			3A.MZ24 (Rocchetta - INGV)
# 			3A.MZ25 (Retrosi 1 - INGV)
# 			3A.MZ26 (Retrosi 2 - INGV)
# 			3A.MZ27 (San Lorenzo a Pinaco - INGV)
# 			3A.MZ28 (Amatrice agriturismo - INGV)
# 			3A.MZ29 (Amatrice Caseificio storico - INGV)
# 			3A.MZ30 (Amatrice Alberghiero - INGV)
# 			3A.MZ31 (Amatrice Fosso in Flysch - INGV)
# 			3A.MZ50 (Pozzo Varoni - IMAA-CNR)
# 			3A.MZ51 (Cornillo Vecchio - IMAA-CNR)
# 			3A.MZ52 (Cossito - IMAA-CNR)
# 			3A.MZ60 (Cascello - IDPA-CNR)
# 			3A.MZ61 (Collepagliuca - IDPA-CNR/IMAA-CNR)
# 			3A.MZ62 (Voceto - IDPA-CNR)
# 			3A.MZ63 (Collecreta - IDPA-CNR/IMAA-CNR)
# 			3A.MZ64 (Capricchia - IDPA-CNR)
# 			5J.SPX2 (Villanova Monteleone)
# 			5J.SPX5 (Torpe)
# 			5J.SPX6 (Siligo)
# 			5J.SPX7 (Ula Tirso (OR))
# 			5J.SPX8 (Bultei)
# 			7C.CS2FF (Cosenza_MIN2_Bor_115gN_(N-->SE))
# 			AC.BCI (Bajram Curri, Albania)
# 			AC.KBN (Korce, Albania)
# 			AC.LSK (Leskovik, Albania)
# 			AC.PHP (Peshkopi, Albania)
# 			AC.PUK (Puke, Albania)
# 			AC.SRN (Sarande, Albania)
# 			AC.VLO (Vlore, Albania)
# 			BA.PZUN (Potenza Universita)
# 			GU.BHB (Bricherasio (TO) - Italy)
# 			GU.BURY (Villa Hanbury (IM) - Italy)
# 			GU.CANO (Canova, Magliolo (SV) - Italy)
# 			GU.CARD (Cardoso-Stazzema(LU) - Italy)
# 			GU.CIRO (Champorcher (AO) - Italy)
# 			GU.ENR (Entracque (CN) - Italy)
# 			GU.EQUI (Equi Terme (MS) - Italy)
# 			GU.GBOS (Grotte di Bossea (CN) - Italy)
# 			GU.GORR (Gorreto (GE) - Italy)
# 			GU.GRAM (Graiana (PR) - Italy)
# 			GU.GSCL (Gusciola (MO) - Italy)
# 			GU.IMI (IMPERIA)
# 			GU.LSD (Lago del Serru` (TO) - Italy)
# 			GU.MAIM (Mastiano (LU) - Italy)
# 			GU.MGRO (Montegrosso Pianlatte)
# 			GU.NEGI (Perinaldo)
# 			GU.PCP (Piancastagna, Ponzone (AL) - Italy)
# 			GU.POPM (Popiglio,Piteglio(PT) - Italy)
# 			GU.PZZ (Stroppo (CN) - Italy)
# 			GU.REMY (St Remy en Bosses(AO)- Italy)
# 			GU.RNCA (Ronca, Sant`Olcese(GE) - Italy)
# 			GU.RORO (Castelbianco (SV) - Italy)
# 			GU.ROTM (Rocchetta Tanaro (AT) - Italy)
# 			GU.RRL (Cesana Torinese (TO) - Italy)
# 			GU.RSP (Reno Superiore (TO) - Italy)
# 			GU.SARM (Sassorosso (LU) - Italy)
# 			GU.SATI (Passo dei Salati (AO) - Italy)
# 			GU.STV (Sant`Anna di Valdieri(CN) - Italy)
# 			GU.TRAV (Traversella (TO) - Italy)
# 			IV.ACER (Acerenza)
# 			IV.AGLI (Aglientu)
# 			IV.AGST (Augusta)
# 			IV.AIO (Antillo, Italy)
# 			IV.ALJA (Alia)
# 			IV.AMUR (Altamura)
# 			IV.AOI (Monte Conero)
# 			IV.APEC (Apecchio)
# 			IV.APPI (Appiano)
# 			IV.APRC (Apricena (FG))
# 			IV.AQT1 (Arquata del Tronto)
# 			IV.ARCI (Arcidosso)
# 			IV.ARRO (Arrone)
# 			IV.ARVD (ARCEVIA 2)
# 			IV.ASOL (Asolo)
# 			IV.ASQU (Asqua)
# 			IV.ASSB (Assisi San Benedetto)
# 			IV.ATBU (AVT - Serra di Burano)
# 			IV.ATCC (AVT - Casa Castalda)
# 			IV.ATFO (Monte Foce - Gubbio)
# 			IV.ATLO (AVT - Montelovesco)
# 			IV.ATMC (Monte Cedrone)
# 			IV.ATMI (AVT - Monte Miggiano)
# 			IV.ATPC (Poggio Castellaccio)
# 			IV.ATPI (Pietralunga - Aviosuperficie)
# 			IV.ATSC (Scheggia)
# 			IV.ATTE (AVT - Monte Tezio)
# 			IV.ATVA (AVT - Monte Valcinella)
# 			IV.ATVO (AVT - Monte Valentino)
# 			IV.BADI (BADIALI)
# 			IV.BAG8 (Bagolino)
# 			IV.BDI (BAGNI DI LUCCA)
# 			IV.BIOG (Camporeale (Ariano Irpino))
# 			IV.BLLA (Bellaria)
# 			IV.BOB (BOBBIO)
# 			IV.BORM (Bormio)
# 			IV.BOTM (Botticino Mattina)
# 			IV.BRES (BRESSANONE)
# 			IV.BRIS (BRISIGHELLA)
# 			IV.BRMO (BORMIO)
# 			IV.BRSN (BARISANO)
# 			IV.BSSO (Busso)
# 			IV.BULG (Bulgheria - Camerota)
# 			IV.CAAM (Accademia Aeronautica Pozzuoli)
# 			IV.CADA (Capodarco)
# 			IV.CAFE (Carife)
# 			IV.CAFI (Castiglion Fiorentino)
# 			IV.CAFL (Arco Felice)
# 			IV.CAFR (Castel Frentano)
# 			IV.CAGG (Caggiano (SA))
# 			IV.CAGR (Agira)
# 			IV.CAMP (CAMPOTOSTO)
# 			IV.CAPA (Cerignola FG)
# 			IV.CAPR (Capriolo)
# 			IV.CAR1 (CAROLEI)
# 			IV.CASP (Castiglione della Pescaia)
# 			IV.CAVE (CAVE)
# 			IV.CAVT (Castelvetrano - Marcita)
# 			IV.CDCA (Citta di Castello)
# 			IV.CDRU (Civita di Ruta - Ottati)
# 			IV.CELB (S.Piero in Campo Elba)
# 			IV.CELI (Celico, Cosenza)
# 			IV.CERA (Filignano)
# 			IV.CERT (CERRETO)
# 			IV.CESI (Cesi-Serravalle di Chienti)
# 			IV.CESX (Cesi)
# 			IV.CET2 (Cetraro)
# 			IV.CFMN (Monte Nuovo)
# 			IV.CGL (PUNTA SERPEDDI)
# 			IV.CIGN (SANT ELIA A PIANISI)
# 			IV.CIMA (Civitanova Marche)
# 			IV.CING (CINGOLI)
# 			IV.CLTA (Licata (Agrigento))
# 			IV.CMDO (CMDO)
# 			IV.CMIS (Faro di Capo Miseno - Stazione Osservatorio Vesuviano)
# 			IV.CMPO (Campotto Po)
# 			IV.CMPR (Campora)
# 			IV.CMSN (Monte S.Angelo)
# 			IV.CNCS (Concesio)
# 			IV.COLB (Campi Flegrei, Galleria Monte Olibano, Stazione Osservatorio)
# 			IV.COR1 (Corinaldo)
# 			IV.CORL (Corleone (Palermo))
# 			IV.CPGN (Carpegna)
# 			IV.CPIS (Campi Flegrei - Fumarola Pisciarelli)
# 			IV.CPOZ (Pozzuoli Darsena -Stazione Osservatorio Vesuviano)
# 			IV.CPTP (Pietraperzia)
# 			IV.CRAC (Craco)
# 			IV.CRE (CAPRESE MICHELANGELO)
# 			IV.CRJA (COSTA RAJA)
# 			IV.CRM1 (Castelraimondo)
# 			IV.CRMI (Carmignano)
# 			IV.CRND (Cornuda)
# 			IV.CRTO (Vesuvio - Cratere Ovest)
# 			IV.CSFT (Campi Flegrei - Cratere Solfatara, Interno)
# 			IV.CSLB (CASTELBUONO)
# 			IV.CSNT (CASTELLINA IN CHIANTI)
# 			IV.CSOB (Solfatara Bordo Cratere - Stazione Osservatorio Vesuviano)
# 			IV.CSP1 (Cessapalombo)
# 			IV.CTI (CASTELLO TESINO)
# 			IV.CTL8 (Castelleone)
# 			IV.DGI (DORGALI GROTTA ISPINIGOLI)
# 			IV.ECHR (Santa Chiara)
# 			IV.ECNV (Catenanuova)
# 			IV.ECTS (CASTIGLIONE)
# 			IV.EL6 (Elcito)
# 			IV.EMCN (Monte Conca)
# 			IV.EMSG (EMSG)
# 			IV.ENIC (ENIC)
# 			IV.EPIT (Pozzo Pitarrone, Linguaglossa, Catania)
# 			IV.EPOZ (EPOZ)
# 			IV.EPZF (Pizzo Felice)
# 			IV.ERBM (EREMO DI BISMANTOVA)
# 			IV.ERC (ERICE)
# 			IV.ESLN (Serra La Nave)
# 			IV.ESML (ESML)
# 			IV.EUCT (Pavia)
# 			IV.EVRN (Santa Venerina)
# 			IV.FAEN (Faenza)
# 			IV.FAGN (FAGNANO)
# 			IV.FANO (Fano)
# 			IV.FAVR (FAVARA 2)
# 			IV.FCOR (Fonte Corniale (PU))
# 			IV.FDMO (Fiordimonte)
# 			IV.FEMA (Monte Fema)
# 			IV.FERS (FERS)
# 			IV.FIAM (FIAMIGNANO)
# 			IV.FIR (Firenze)
# 			IV.FIU (FONDO FIUMICELLO (MINERBIO))
# 			IV.FIU1 (Fiuminata)
# 			IV.FNVD (FONTANA VIDOLA)
# 			IV.FOSV (Fossato di Vico)
# 			IV.FRE8 (Fregona)
# 			IV.FRES (Fresagrandinaria)
# 			IV.FRON (Frontone)
# 			IV.FROS (Frosini)
# 			IV.FSSB (FOSSOMBRONE)
# 			IV.FVI (FORNI AVOLTRI)
# 			IV.GAG1 (Gagliole)
# 			IV.GALF (Gagliano Castelferrato)
# 			IV.GATE (Gambatesa)
# 			IV.GAVE (Gavelli)
# 			IV.GIB (GIBILMANNA)
# 			IV.GIGS (GIGS)
# 			IV.GIUL (GIULIANO DI ROMA)
# 			IV.GMB (GAMBARIE)
# 			IV.GRI (GIRIFALCO)
# 			IV.GRIS (Grisolia)
# 			IV.GROG (Isola di Gorgona)
# 			IV.GUAR (GUARCINO)
# 			IV.GUMA (Gualdo di Macerata)
# 			IV.HAGA (HYBLEAN AUGUSTA)
# 			IV.HAVL (Avola)
# 			IV.HBSP (Bosco Santo  Pietro (Catania))
# 			IV.HCRL (Carlentini)
# 			IV.HLNI (Lentini Masseria Cucco)
# 			IV.HMDC (Modica)
# 			IV.HPAC (HPAC)
# 			IV.HVZN (Vizzini)
# 			IV.IACL (ALICUDI)
# 			IV.IFIL (Filicudi)
# 			IV.IFOR (Ischia - Faro Punta Imperatore)
# 			IV.ILOS (Lipari Observatory)
# 			IV.IMOL (Imola)
# 			IV.IMTC (Ischia - Monte Corvo)
# 			IV.INTR (INTRODACQUA)
# 			IV.IOCA (Ischia - Osservatorio Casamicciola)
# 			IV.IST3 (Stromboli-Oss. Fiorentini)
# 			IV.ISTR (Ginostra)
# 			IV.IVGP (Grotta Palizzi Isola di Vulcano)
# 			IV.IVPL (Vulcano Piano)
# 			IV.IVUG (Isola Vulcano Grillo)
# 			IV.JOPP (Joppolo)
# 			IV.LADO (San Nicola dell Alto)
# 			IV.LATB (Latina borehole)
# 			IV.LATE (Latera)
# 			IV.LAV9 (LANUVIO)
# 			IV.LEOD (Capriano del Colle)
# 			IV.LIK (LIK)
# 			IV.LINA (Isola di Linosa)
# 			IV.LMD (LMD)
# 			IV.LNSS (LEONESSA)
# 			IV.LPDG (LPDG)
# 			IV.LPEL (Lama dei Peligni)
# 			IV.LRP (Arpino)
# 			IV.LTRZ (LATERZA)
# 			IV.MA9 (MARINO)
# 			IV.MABI (MALGA BISSINA)
# 			IV.MAGA (Magasa)
# 			IV.MAGO (Magona)
# 			IV.MAON (MONTE ARGENTARIO)
# 			IV.MARS (Marsala)
# 			IV.MBAL (Monte Baldo Osservatorio Astronomico Novezzina)
# 			IV.MC2 (Monte Cornaccione)
# 			IV.MCEL (Monticello)
# 			IV.MCI (Montecassino)
# 			IV.MCIF (Montecalvo in Foglia)
# 			IV.MCIV (Monte Civitella)
# 			IV.MCPD (Capo Orlando (Messina))
# 			IV.MCRV (Calabritto - Mt. Cervialto)
# 			IV.MCSR (Castroreale)
# 			IV.MCT (MONTECAMMARATA)
# 			IV.MDAR (Monte Daria)
# 			IV.MDI (MONTE DI NESE)
# 			IV.MELA (Melanico - S. Croce di Magliano)
# 			IV.MERA (Merate)
# 			IV.MESG (Mesagne)
# 			IV.MEU (MONTE LAURO)
# 			IV.MF5 (Montefalcone Appennino)
# 			IV.MFNL (MONTE FINESTRELLE)
# 			IV.MGAB (Montegabbione)
# 			IV.MGR (MORIGERATI)
# 			IV.MIDA (MIRANDA)
# 			IV.MIGL (Miglionico)
# 			IV.MILN (Milano)
# 			IV.MILZ (Milazzo Faro)
# 			IV.MMGO (MONTE MAGAGGIARO)
# 			IV.MMN (MORMANNO)
# 			IV.MMO1 (Montemonaco)
# 			IV.MMUR (Monte Murano)
# 			IV.MNO (MONTE SORO)
# 			IV.MNTP (Montappone)
# 			IV.MNTT (Montottone)
# 			IV.MNTV (Mantova)
# 			IV.MOCL (Montecuccoli)
# 			IV.MOCO (Biccari - Monte Cornacchia)
# 			IV.MODE (Modena)
# 			IV.MODR (Mondragone)
# 			IV.MOMA (Monte Martano)
# 			IV.MONC (Moncucco Torinese)
# 			IV.MPAG (Monte Paganuccio)
# 			IV.MPAZ (Palizzi)
# 			IV.MPG (MONTE PELLEGRINO)
# 			IV.MPNC (San Pier Niceto, gia PORTELLA MANDANICI)
# 			IV.MPPT (Montemurlo)
# 			IV.MRB1 (MONTE ROCCHETTA)
# 			IV.MRGE (Morge)
# 			IV.MRLC (Muro Lucano)
# 			IV.MRVN (Minervino Murge)
# 			IV.MSAG (Monte S. Angelo)
# 			IV.MSCL (SCILLA)
# 			IV.MSFR (San Fratello)
# 			IV.MSRU (POGGIO SCUDEARU)
# 			IV.MSSA (Maissana)
# 			IV.MTCE (MONTECELIO)
# 			IV.MTCR (MTCR)
# 			IV.MTGR (MONTAGNA GRANDE)
# 			IV.MTL1 (Matelica)
# 			IV.MTMR (Montemarano(AV))
# 			IV.MTRA (Matera di Acquasanta Terme (AP))
# 			IV.MTRZ (Monterenzio)
# 			IV.MTSN (Montesano sulla Marcellana)
# 			IV.MTTG (MOTTA SAN GIOVANNI)
# 			IV.MUCR (Ucria)
# 			IV.MURB (MONTE URBINO)
# 			IV.NARO (Abbazia di Naro)
# 			IV.NDIM (Novi di Modena)
# 			IV.NEVI (Neviano degli Arduini)
# 			IV.NOCI (Noci)
# 			IV.NOV (Novara di Sicilia)
# 			IV.NRCA (NORCIA)
# 			IV.OFFI (Offida)
# 			IV.OPPE (Oppeano)
# 			IV.ORI (ORIOLO CALABRO)
# 			IV.ORZI (Orzinuovi)
# 			IV.OSSC (OSSC)
# 			IV.OVO (OSSERVATORIO VESUVIANO)
# 			IV.PALZ (Palazzo San Gervasio)
# 			IV.PAOL (Paolisi)
# 			IV.PARC (Parchiule)
# 			IV.PCRO (Pietralacroce (Ancona))
# 			IV.PE3 (Peglio)
# 			IV.PESA (PESARO)
# 			IV.PETRA (Petralia Soprana)
# 			IV.PF6 (Pievefavera)
# 			IV.PIEI (PIEIA)
# 			IV.PIGN (Pignataro Maggiore (CE))
# 			IV.PII (PISA)
# 			IV.PIO1 (Pioraco)
# 			IV.PIPA (Pietrapaola)
# 			IV.PLAC (Placanica)
# 			IV.PLLN (POLLINA)
# 			IV.PLMA (Palmaria-Portovenere)
# 			IV.POFI (Posta Fibreno)
# 			IV.PP3 (PP3)
# 			IV.PRMA (Parma)
# 			IV.PSB1 (PESCO SANNITA)
# 			IV.PTCC (PATOCCO)
# 			IV.PTMD (Pantelleria - Kuddia Mida)
# 			IV.PTQR (PIETRAQUARIA)
# 			IV.PTRJ (Pietraroja)
# 			IV.PTRP (PIETRAPERTOSA)
# 			IV.QLNO (QUILIANO)
# 			IV.RAFF (Raffo Rosso)
# 			IV.RAVA (RAVARINO)
# 			IV.RCAV (Rocca di Cave)
# 			IV.RDP (ROCCA DI PAPA)
# 			IV.RESU (Resuttano)
# 			IV.RIBO (RIBO)
# 			IV.RM33 ()
# 			IV.RMP (MONTE PORZIO CATONE)
# 			IV.RNI2 (RIONERO SANNITICO)
# 			IV.ROM9 (ROMA (sede INGV))
# 			IV.ROVR (Rovere  Veronese)
# 			IV.RSM2 (Repubblica San Marino)
# 			IV.RUFI (RUFI)
# 			IV.SACR (S. CROCE DEL SANNIO)
# 			IV.SACS (San Casciano dei Bagni)
# 			IV.SAIV (Sant Angelo in Vado (PU))
# 			IV.SALB (San Lorenzo Bellizzi)
# 			IV.SALO (Salo)
# 			IV.SAMA (S.Maria delle Mole (Ciampino, Roma))
# 			IV.SANR (Sandrigo)
# 			IV.SAP2 (Sant Angelo in Pontano (MC))
# 			IV.SARZ (Sarezzano)
# 			IV.SBPO (S.Benedetto Po)
# 			IV.SCHR (S. CHIRICO RAPARO)
# 			IV.SCTE (Santa Cesarea Terme)
# 			IV.SEF1 (Sefro)
# 			IV.SEI (SANT AGATA)
# 			IV.SENI (Senigallia)
# 			IV.SERM (Semide)
# 			IV.SERS (Sersale)
# 			IV.SFI (SANTA SOFIA)
# 			IV.SGG (S.Gregorio Matese)
# 			IV.SGRT (San Giovanni Rotondo)
# 			IV.SGTA (Sant Agata di Puglia)
# 			IV.SIRI (Monte Sirino - Moliterno)
# 			IV.SLCN (SALA CONSILINA)
# 			IV.SMA1 (San Martino)
# 			IV.SNAL (S. Angelo dei Lombardi)
# 			IV.SNTG (ESANATOGLIA)
# 			IV.SOI (SAMO)
# 			IV.SOLUN (SOLUNTO)
# 			IV.SPS2 (Spezzano Piccolo)
# 			IV.SRES (Monte Soratte)
# 			IV.SSFR (Montelago di Sassoferrato)
# 			IV.SSM1 (San Severino Marche)
# 			IV.SSP9 (Sansepolcro)
# 			IV.SSY (SORTINO)
# 			IV.STAL (Staligial)
# 			IV.STR4 (STROMBOLI 4)
# 			IV.STRG (Stromboli-Localit.. Labronzo)
# 			IV.T0104 (Madonna delle Grazie (Coppito) - AQ)
# 			IV.T0110 (Collepietro - AQ)
# 			IV.T0701 (Mormanno)
# 			IV.T0702 (Mormanno)
# 			IV.T1101 (Campochiaro (CB))
# 			IV.T1201 (Domo (RI))
# 			IV.T1202 (Villanova (RI))
# 			IV.T1204 (Cossito (RI))
# 			IV.T1211 (Morro Reatino RI)
# 			IV.T1212 (Avendita PG)
# 			IV.T1213 (Savelli PG)
# 			IV.T1214 (Forca Canapine AP)
# 			IV.T1215 (Reggiano PG)
# 			IV.T1216 (Castelvecchio PG)
# 			IV.T1217 (Poggiodomo PG)
# 			IV.T1218 (Civita PG)
# 			IV.T1219 (Massaprofoglio MC)
# 			IV.T1220 (Baregnano MC)
# 			IV.T1221 (Spina Nuova PG)
# 			IV.T1222 (Castel Sant Angelo, Loc. Ville (RI))
# 			IV.T1241 (Roccafluvione, Frazione Osoli  Ascoli Piceno)
# 			IV.T1242 (Castelluccio di Norcia Perugia)
# 			IV.T1243 (Rocca Santa Maria, Loc. Ceppo (TE))
# 			IV.T1244 (Spelonga)
# 			IV.T1245 (Castelsantangelo Sul Nera Macerata)
# 			IV.T1246 (Crognaleto)
# 			IV.T1247 (Pizzoli)
# 			IV.T1256 (Bolognola Macerata)
# 			IV.T1299 (T1299)
# 			IV.TB01 (Gubbio)
# 			IV.TB02 (Pietralunga)
# 			IV.TB03 (Pietralunga)
# 			IV.TDS (TERRANOVA DA SIBARI)
# 			IV.TEOL (Teolo)
# 			IV.TERO (TERAMO)
# 			IV.TOLF (TOLFA)
# 			IV.TRE1 (Treia)
# 			IV.TREG (Tregnago)
# 			IV.TREM (ISOLE TREMITI - SAN NICOLA)
# 			IV.TRIF (Trifonti)
# 			IV.TRIV (Trivento)
# 			IV.TRTR (Tortoreto Alta)
# 			IV.USI (USTICA)
# 			IV.VAGA (Valle Agricola)
# 			IV.VARE (Varese)
# 			IV.VARP (Vesuvio - Array Permanente)
# 			IV.VBKN (Vesuvio - Bunker Nord, Stazione Osservatorio Vesuviano)
# 			IV.VCEL (VILLA CELIERA)
# 			IV.VCNE (Vesuvio Cratere Nord-Est - Stazione Osservatorio Vesuviano)
# 			IV.VCRE (Vesuvio - Cratere Est, Stazione Osservatorio Vesuviano)
# 			IV.VENL (Venezia Lido)
# 			IV.VENT (VENTOTENE)
# 			IV.VITU (Vitulano)
# 			IV.VIVA (Vivaro)
# 			IV.VMG (VILLORE DEL MUGELLO)
# 			IV.VOBA (Vobarno)
# 			IV.VTIR (Vesuvio - Forestale)
# 			IV.VULT (Monte Vulture - Melfi)
# 			IV.VVDG (Vesuvio Valle del Gigante)
# 			IV.VVLD (VILLAVALLELONGA)
# 			IV.ZCCA (ZOCCA)
# 			IV.ZEN8 (San Zeno di Montagna)
# 			IV.ZONE (ZONE)
# 			IV.ZOVE (Zovencedo)
# 			IX.AND3 (Station Andretta, Italy)
# 			IX.AVG3 (Station Avigliano, Italy)
# 			IX.BEL3 (Station Bella, Italy)
# 			IX.BENI (Station Universita` Del Sannio, Italy)
# 			IX.BSC3 (Station Bisaccia, Italy)
# 			IX.CGG3 (Station Caggiano, Italy)
# 			IX.CLT3 (Station Calitri, Italy)
# 			IX.CMP3 (Station Campagna, Italy)
# 			IX.COL3 (Station Colliano, Italy)
# 			IX.CSG3 (Station Toppo Di Castelgrande (Osservatorio Astronomico), It)
# 			IX.LGS3 (Station Luogosano, Italy)
# 			IX.LIO3 (Station Lioni, Italy)
# 			IX.MNT3 (Station Montella, Italy)
# 			IX.MRN3 (Station Marsico Nuovo (PZ), Italy)
# 			IX.NAPI (Station Complesso Universitario Monte Sant`Angelo, Italy)
# 			IX.NSC3 (Station Nusco, Italy)
# 			IX.PGN3 (Station Pignola, Italy)
# 			IX.PST3 (Station Postiglione, Italy)
# 			IX.RDM3 (Station Ruvo Del Monte, Italy)
# 			IX.RSF3 (Station Rocca San Felice, Italy)
# 			IX.SALI (Station CIMA - Sant`Angelo dei Lombardi, Italy)
# 			IX.SCL3 (Station Muro Lucano (Serra Campolungo), Italy)
# 			IX.SFL3 (Station San Fele, Italy)
# 			IX.SNR3 (Station Senerchia, Italy)
# 			IX.SRN3 (Station Sant`Arsenio, Italy)
# 			IX.SSB3 (Station San Sossio Baronia, Italy)
# 			IX.STN3 (Station Satriano, Italy)
# 			IX.TEGI (Station Teggiano - Istituto P. Leto, Italy)
# 			IX.VDP3 (Station Vietri Di Potenza, Italy)
# 			IX.VDS3 (Station Muro Lucano (Varco Staccarino), Italy)
# 			IX.VGG3 (Station Viggiano (Prot.Civ.Gr.Lucano), Italy)
# 			MN.AQU (L'Aquila, Italy)
# 			MN.ARPR (Arapgir, Turkey)
# 			MN.BLY (Banja Luka, Bosnia and Herzegovina)
# 			MN.BNI (Bardonecchia, Italy)
# 			MN.BZS (Buzias, Romania)
# 			MN.CEL (Celeste, Italy)
# 			MN.CLTB (Caltabellotta, Italy)
# 			MN.CUC (Castrocucco, Italy)
# 			MN.DIVS (Divcibare, Serbia)
# 			MN.DPC (Dobruska/Polom, Czech Republic)
# 			MN.IDI (Anogia, Greece)
# 			MN.ISP (Isparta, Turkey)
# 			MN.KEK (Kerkira Island, Greece)
# 			MN.KLV (Kalavryta, Achaia, Greece)
# 			MN.PDG (Podgorica, Montenegro)
# 			MN.RTC (Rabat, Morocco)
# 			MN.THL (Klokotos, Thessalia, Greece)
# 			MN.TIP (Timpagrande, Italy)
# 			MN.TIR (Tirana, Albania)
# 			MN.TNV (Terra Nova Bay, Antarctica)
# 			MN.TRI (Trieste, Italy)
# 			MN.TUE (Stuetta, Italy)
# 			MN.VAE (Valguarnera, Italy)
# 			MN.VLC (Villacollemandina, Italy)
# 			MN.VSL (Villasalto, Italy)
# 			MN.VTS (Vitosha, Bulgary)
# 			MN.WDD (Wied Dalam, Malta)
# 			NI.DST2 (Trieste Universita DST, Italy)
# 			NI.PALA (Monte Pala, Italy)
# 			NI.POLC (Polcenigo, Italy)
# 			NI.PURA (Passo Pura, Italy)
# 			NI.VINO (Villanova, Italy)
# 			OT.TAR1 (Taranto)
# 			OX.ACOM (Acomizza, Italy)
# 			OX.AGOR (Agordo, Italy)
# 			OX.BAD (Bernadia, Italy)
# 			OX.BALD (Monte Baldo, Italy)
# 			OX.BOO (Bordano, Italy)
# 			OX.CAE (Caneva, Italy)
# 			OX.CGRP (Cima Grappa, Italy)
# 			OX.CIMO (Cimolais, Italy)
# 			OX.CLUD (Cludinico, Italy)
# 			OX.DRE (Drenchia, Italy)
# 			OX.FUSE (Fusea, Italy)
# 			OX.MARN (Marana, Italy)
# 			OX.MLN (Malnisio, Italy)
# 			OX.MPRI (Monte Prat, Italy)
# 			OX.PLRO (Paularo, Italy)
# 			OX.PRED (Cave del Predil, Italy)
# 			OX.SABO (Monte Sabotino, Italy)
# 			OX.VARN (Col Varnada, Italy)
# 			OX.ZOU2 (Zoufplan, Italy)
# 			RF.GEPF (Gemona Piazza del Ferro)
# 			SI.ABSI (Aberstuckl (Sarntal))
# 			SI.BOSI (Bozen/Zivilschutz Zentrale)
# 			SI.KOSI (Kohlern/Titschen)
# 			SI.LUSI (Lusi)
# 			SI.MOSI (Grossmontoni/Vinschgau)
# 			SI.RISI (Rein in Taufers/Ahrntal)
# 			SI.ROSI (Rosskopf/Sterzing)
# 			ST.CARE (Lago Careser)
# 			ST.DOSS (DOSS)
# 			ST.GAGG (Gaggia)
# 			ST.OZOL (Ozolo)
# 			ST.PANI (Panarotta)
# 			ST.RONC (Roncone)
# 			ST.VARA (Varagna)
# 			ST.ZIAN (Ziano)
# 			TV.AG11 (Viggiano (PZ))
# 			TV.AG51 (Grumento Nova (PZ))
# 			TV.H2O5 (Montecassino)
# 			TV.SF01 (Poggio Pratacci)
# 			TV.SF03 (Valle Cupa)
# 			TV.SF04 (Casetta)
# 			TV.SF11 (Podere del Sole)
# 			TV.SF13 (Bagnolo)
# 			TV.SF14 (Selvena)
# 			TV.SU26 (Carbonia Iglesias, Loc. Su Bruncu (CI))
# 			TV.TN05 (Corleto Perticara (PZ))
# 			TV.TT08 (Gorgoglione (MT))
# 			XO.AM01 (Torre del Podestà, Amandola)
# 			XO.AM02 (Istituto Tecnico, Amandola)
# 			XO.AM03 (Ospedale, Amandola)
# 			XO.AM04 (Base Costone Ospedale, Amandola)
# 			XO.AM05 (Amandola (FM) Campo sportivo)
# 			XO.CP01 (Capitignano campo calcio)
# 			XO.CP02 (Mopolino Via Repubblica Signora Angela)
# 			XO.CP04 (Mopolino via del Fosso)
# 			XO.CP05 (Capitignano via di Sopra)
# 			XO.CP06 (Capitignano Paterno campetto)
# 			XO.CP07 (Giardino di un ex asilo a San Giovanni Paganica (AQ))
# 			XO.CV01 (Falsabraga in Fortezza, Civitella del Tronto)
# 			XO.CV02 (c/o Porta Napoli in L. Vinciguerra, Civitella del Tronto)
# 			XO.CV03 (Via Salinello, Civitella del Tronto)
# 			XO.CV04 (Edificio privato in via Roma 88, Civitella del Tronto)
# 			XO.CV05 (Parte terminale di via del Parnaso, Civitella del Tronto)
# 			XO.MB01 (Capitignano)
# 			XO.MB02 (Pago - Rovagnano)
# 			XO.MB03 (Capitignano - Terreno De Andreis)
# 			XO.MB04 (Capitignano)
# 			XO.MB05 (Capitignano - Stadio)
# 			XO.MB06 (Piedicolle)
# 			XO.MB07 (Marignano)
# 			XO.MB08 (Capitignano - Piazza V x Cavo)
# 			XO.MB09 (Paterno - Campetto)
# 			XO.MB10 (Capitignano - Porcareccia)
# 			XO.MB12 (Montereale)
# 			XO.MN02 (Montereale PiediColle Trocchi)
# 			XO.MN03 (Montereale PiediColle Di Loreto)
# 			XO.MN04 (Montereale isola ecologica)
# 			XO.MN06 (Montereale ex municipio ran)
# 			XO.MN08 (Montereale ex prefettura)
# 			XO.MN09 (Montereale ex prefettura)
# 			XO.SGF1 (San Giovanni - Via della Montagna)
# 			XO.SGF2 (San Giovanni)
# 			XO.SGF3 (San Giovanni - cava diurna a 40 metri verso nord)
# 			XO.SGF5 (San Giovanni - cava dismessa)
# 			XO.SGF6 (San Giovanni)
# 			XO.SGF7 (San Giovanni - dentro recinto picnic vicino palizzata)
# 			XO.SGFR (San Giovanni)
# 			Z3.A300A (Muzzana del Turgnano (UD))
# 			Z3.A301A (Isiata (VE))
# 			Z3.A302A (Resana (TV))
# 			Z3.A303A (Lido-Pellestrina (VE))
# 			Z3.A304A (Bellombra (RO))
# 			Z3.A305A (Porto Tolle (RO), Italy)
# 			Z3.A306A (Viano (RE), Italy)
# 			Z3.A307A (Bentivoglio (BO), Italy)
# 			Z3.A308A (Longastrino (FE), Italy)
# 			Z3.A309A (Martorano (FC), Italy)
# 			Z3.A312A (Bozzolo (MN))
# 			Z3.A313A (Volta Mantovana (MN))
# 			Z3.A316A (Montecristo (LI))
# 			Z3.A317A (Capraia (LI))
# 			IV.ASSB..HHE, IV.ASSB..LHZ, IV.ASSB..LHN, IV.ASSB..LHE,
# 			IV.ASSB..VHZ, IV.ASSB..VHN, IV.ASSB..VHE, IV.ATBU..EHZ,
# 			IV.ATBU..EHN, IV.ATBU..EHE, IV.ATCC..EHZ, IV.ATCC..EHN,
# 			IV.ATCC..EHE, IV.ATCC..HNZ, IV.ATCC..HNN, IV.ATCC..HNE,
# 			IV.ATFO..BHZ, IV.ATFO..BHN, IV.ATFO..BHE, IV.ATFO..HHZ,
# 			IV.ATFO..HHN, IV.ATFO..HHE, IV.ATFO..HNZ, IV.ATFO..HNN,
# 			IV.ATFO..HNE, IV.ATFO..LHZ, IV.ATFO..LHN, IV.ATFO..LHE,
# 			IV.ATFO..VHZ, IV.ATFO..VHN, IV.ATFO..VHE, IV.ATLO..EHZ,
# 			IV.ATLO..EHN, IV.ATLO..EHE, IV.ATLO..HNZ, IV.ATLO..HNN,
# 			IV.ATLO..HNE, IV.ATMC..EHZ, IV.ATMC..EHN, IV.ATMC..EHE,
# 			IV.ATMI..BHZ, IV.ATMI..BHN, IV.ATMI..BHE, IV.ATMI..HHZ,
# 			IV.ATMI..HHN, IV.ATMI..HHE, IV.ATMI..LHZ, IV.ATMI..LHN,
# 			IV.ATMI..LHE, IV.ATMI..VHZ, IV.ATMI..VHN, IV.ATMI..VHE,
# 			IV.ATPC..BHZ, IV.ATPC..BHN, IV.ATPC..BHE, IV.ATPC..HHZ,
# 			IV.ATPC..HHN, IV.ATPC..HHE, IV.ATPC..HNZ, IV.ATPC..HNN,
# 			IV.ATPC..HNE, IV.ATPC..LHZ, IV.ATPC..LHN, IV.ATPC..LHE,
# 			IV.ATPC..VHZ, IV.ATPC..VHN, IV.ATPC..VHE, IV.ATPI..EHZ,
# 			IV.ATPI..EHN, IV.ATPI..EHE, IV.ATSC..EHZ, IV.ATSC..EHN,
# 			IV.ATSC..EHE, IV.ATTE..BHZ, IV.ATTE..BHN, IV.ATTE..BHE,
# 			IV.ATTE..HHZ, IV.ATTE..HHN, IV.ATTE..HHE, IV.ATTE..HNZ,
# 			IV.ATTE..HNN, IV.ATTE..HNE, IV.ATTE..LHZ, IV.ATTE..LHN,
# 			IV.ATTE..LHE, IV.ATTE..VHZ, IV.ATTE..VHN, IV.ATTE..VHE,
# 			IV.ATVA..EHZ, IV.ATVA..EHN, IV.ATVA..EHE, IV.ATVO..BHZ,
# 			IV.ATVO..BHN, IV.ATVO..BHE, IV.ATVO..HHZ, IV.ATVO..HHN,
# 			IV.ATVO..HHE, IV.ATVO..HNZ, IV.ATVO..HNN, IV.ATVO..HNE,
# 			IV.ATVO..LHZ, IV.ATVO..LHN, IV.ATVO..LHE, IV.ATVO..VHZ,
# 			IV.ATVO..VHN, IV.ATVO..VHE, IV.BADI..EHZ, IV.BADI..EHN,
# 			IV.BADI..EHE, IV.BAG8..HNZ, IV.BAG8..HNN, IV.BAG8..HNE,
# 			IV.BDI..BHZ (2x), IV.BDI..BHN (2x), IV.BDI..BHE (2x),
# 			IV.CING..VHE, IV.CLTA..HHZ, IV.CLTA..HHN, IV.CLTA..HHE,
# 			IV.CMDO..BHZ, IV.CMDO..BHN, IV.CMDO..BHE, IV.CMDO..HHZ,
# 			IV.CMDO..HHN, IV.CMDO..HHE, IV.CMDO..LHZ, IV.CMDO..LHN,
# 			IV.CMDO..LHE, IV.CMDO..VHZ, IV.CMDO..VHN, IV.CMDO..VHE,
# 			IV.CMIS..HHZ, IV.CMIS..HHN, IV.CMIS..HHE, IV.CMPO..HNZ,
# 			IV.CMPO..HNN, IV.CMPO..HNE, IV.CMPR..BHZ, IV.CMPR..BHN,
# 			IV.CMPR..BHE, IV.CMPR..HHZ, IV.CMPR..HHN, IV.CMPR..HHE,
# 			IV.CMPR..LHZ, IV.CMPR..LHN, IV.CMPR..LHE, IV.CMPR..VHZ,
# 			IV.CMPR..VHN, IV.CMPR..VHE, IV.CMSN..HHZ, IV.CMSN..HHN,
# 			IV.CMSN..HHE, IV.CNCS..HNZ, IV.CNCS..HNN, IV.CNCS..HNE,
# 			IV.COLB..HHZ, IV.COLB..HHN, IV.COLB..HHE, IV.COR1..EHZ,
# 			IV.COR1..EHN, IV.COR1..EHE, IV.COR1..HNZ, IV.COR1..HNN,
# 			IV.COR1..HNE, IV.CORL..BHZ, IV.CORL..BHN, IV.CORL..BHE,
# 			IV.CORL..HHZ, IV.CORL..HHN, IV.CORL..HHE, IV.CORL..LHZ,
# 			IV.CORL..LHN, IV.CORL..LHE, IV.CORL..VHZ, IV.CORL..VHN,
# 			IV.CORL..VHE, IV.CPGN..EHZ, IV.CPGN..EHN, IV.CPGN..EHE,
# 			IV.CPGN..HNZ, IV.CPGN..HNN, IV.CPGN..HNE, IV.CPIS..HHZ,
# 			IV.CPIS..HHN, IV.CPIS..HHE, IV.CPOZ..HHZ, IV.CPOZ..HHN,
# 			IV.CPOZ..HHE, IV.CPTP..HHZ, IV.CPTP..HHN, IV.CPTP..HHE,
# 			IV.CRAC..EHZ, IV.CRAC..EHN, IV.CRAC..EHE, IV.CRE..BHZ, IV.CRE..BHN
# 			IV.CRE..BHE, IV.CRE..HHZ, IV.CRE..HHN, IV.CRE..HHE, IV.CRE..LHZ,
# 			IV.CRE..LHN, IV.CRE..LHE, IV.CRE..VHZ, IV.CRE..VHN, IV.CRE..VHE,
# 			IV.CRJA..HHZ, IV.CRJA..HHN, IV.CRJA..HHE, IV.CRJA..SHZ,
# 			IV.CRM1..HNZ, IV.CRM1..HNN, IV.CRM1..HNE, IV.CRMI..BHZ,
# 			IV.CRMI..BHN, IV.CRMI..BHE, IV.CRMI..HHZ, IV.CRMI..HHN,
# 			IV.CRMI..HHE, IV.CRMI..HNZ, IV.CRMI..HNN, IV.CRMI..HNE,
# 			IV.CRMI..LHZ, IV.CRMI..LHN, IV.CRMI..LHE, IV.CRMI..VHZ,
# 			IV.CRMI..VHN, IV.CRMI..VHE, IV.CRND..HNZ, IV.CRND..HNN,
# 			IV.CRND..HNE, IV.CRTO..HHZ, IV.CRTO..HHN, IV.CRTO..HHE,
# 			MN.BZS..BHN, MN.BZS..BHE, MN.BZS..HHZ, MN.BZS..HHN, MN.BZS..HHE,
# 			MN.BZS..LHZ, MN.BZS..LHN, MN.BZS..LHE, MN.BZS..VHZ, MN.BZS..VHN,
# 			MN.BZS..VHE, MN.CEL..BHZ (2x), MN.CEL..BHN (2x), MN.CEL..BHE (2x),
# 			MN.CEL..HHZ (2x), MN.CEL..HHN (2x), MN.CEL..HHE (2x),
# 			MN.CEL..HNZ (2x), MN.CEL..HNN (2x), MN.CEL..HNE (2x),
# 			MN.CEL..LHZ (2x), MN.CEL..LHN (2x), MN.CEL..LHE (2x), MN.CEL..UHZ,
# 			MN.CEL..UHN, MN.CEL..UHE, MN.CEL..VHZ (2x), MN.CEL..VHN (2x),
# 			MN.CEL..VHE (2x), MN.CLTB..BHZ, MN.CLTB..BHN, MN.CLTB..BHE,
# 			MN.CLTB..HHZ, MN.CLTB..HHN, MN.CLTB..HHE, MN.CLTB..LHZ,
# 			MN.CLTB..LHN, MN.CLTB..LHE, MN.CLTB..VHZ, MN.CLTB..VHN,
# 			MN.CLTB..VHE, MN.CUC..BHZ (2x), MN.CUC..BHN (2x), MN.CUC..BHE (2x)
# 			MN.CUC..HHZ (2x), MN.CUC..HHN (2x), MN.CUC..HHE (2x),
# 			MN.CUC..HNZ (2x), MN.CUC..HNN (2x), MN.CUC..HNE (2x),
# 			MN.CUC..LHZ (2x), MN.CUC..LHN (2x), MN.CUC..LHE (2x), MN.CUC..UHZ,
# 			MN.CUC..UHN, MN.CUC..UHE, MN.CUC..VHZ (2x), MN.CUC..VHN (2x),
# 			MN.CUC..VHE (2x), MN.DIVS..BHZ, MN.DIVS..BHN, MN.DIVS..BHE,
# 			MN.DIVS..LHZ, MN.DIVS..LHN, MN.DIVS..LHE, MN.DIVS..UHZ,
# 			MN.DIVS..UHN, MN.DIVS..UHE, MN.DIVS..VHZ, MN.DIVS..VHN,
# 			MN.DIVS..VHE, MN.DPC..BHZ, MN.DPC..BHN, MN.DPC..BHE, MN.DPC..HHZ,
# 			MN.DPC..HHN, MN.DPC..HHE, MN.IDI..BHZ (2x), MN.IDI..BHN (2x),
# 			MN.IDI..BHE (2x), MN.IDI..HHZ (2x), MN.IDI..HHN (2x),
# 			MN.IDI..HHE (2x), MN.IDI..LHZ (2x), MN.IDI..LHN (2x),
# 			MN.IDI..LHE (2x), MN.IDI..UHZ, MN.IDI..UHN, MN.IDI..UHE,
# 			MN.IDI..VHZ, MN.IDI..VHN, MN.IDI..VHE, MN.ISP.00.BHZ, MN.ISP.00.BHN
# 			MN.ISP.00.BHE, MN.ISP.00.LHZ, MN.ISP.00.LHN, MN.ISP.00.LHE,
# 			MN.ISP.00.VHZ, MN.ISP.00.VHN, MN.ISP.00.VHE, MN.KEK..BHZ,
# 			MN.KEK..BHN, MN.KEK..BHE, MN.KEK..HHZ, MN.KEK..HHN, MN.KEK..HHE,
# 			MN.KEK..LHZ, MN.KEK..LHN, MN.KEK..LHE, MN.KEK..VHZ, MN.KEK..VHN,
# 			OT.TAR1..HHZ, OT.TAR1..HHN, OT.TAR1..HHE, OX.ACOM..HHZ,
# 			OX.ACOM..HHN, OX.ACOM..HHE, OX.ACOM..HNZ, OX.ACOM..HNN,
# 			OX.ACOM..HNE, OX.AGOR..HHZ, OX.AGOR..HHN, OX.AGOR..HHE,
# 			OX.AGOR..HNZ, OX.AGOR..HNN, OX.AGOR..HNE, OX.BAD..BHZ, OX.BAD..BHN
# 			OX.BAD..BHE, OX.BAD..HHZ, OX.BAD..HHN, OX.BAD..HHE, OX.BAD..HNZ,
# 			OX.BAD..HNN, OX.BAD..HNE, OX.BAD..LHZ, OX.BAD..LHN, OX.BAD..LHE,
# 			OX.BAD..VHZ, OX.BAD..VHN, OX.BAD..VHE, OX.BALD..BHZ, OX.BALD..BHN,
# 			OX.BALD..BHE, OX.BALD..HHZ, OX.BALD..HHN, OX.BALD..HHE,
# 			OX.BALD..HNZ, OX.BALD..HNN, OX.BALD..HNE, OX.BALD..LHZ,
# 			OX.BALD..LHN, OX.BALD..LHE, OX.BALD..VHZ, OX.BALD..VHN,
# 			OX.BALD..VHE, OX.BOO..HHZ, OX.BOO..HHN, OX.BOO..HHE, OX.BOO..HNZ,
# 			OX.BOO..HNN, OX.BOO..HNE, OX.CAE..HHZ, OX.CAE..HHN, OX.CAE..HHE,
# 			OX.CGRP..BHZ, OX.CGRP..BHN, OX.CGRP..BHE, OX.CGRP..HHZ,
# 			OX.CGRP..HHN, OX.CGRP..HHE, OX.CGRP..HNZ, OX.CGRP..HNN,
# 			OX.CGRP..HNE, OX.CIMO..HHZ (2x), OX.CIMO..HHN (2x),
# 			OX.CIMO..HHE (2x), OX.CIMO..HNZ (2x), OX.CIMO..HNN (2x),
# 			OX.CIMO..HNE (2x), OX.CLUD..HHZ, OX.CLUD..HHN, OX.CLUD..HHE,
# 			OX.CLUD..HNZ, OX.CLUD..HNN, OX.CLUD..HNE, OX.DRE..BHZ, OX.DRE..BHN
# 			OX.DRE..BHE, OX.DRE..HHZ, OX.DRE..HHN, OX.DRE..HHE, OX.DRE..HNZ,
# 			OX.DRE..HNN, OX.DRE..HNE, OX.DRE..LHZ, OX.DRE..LHN, OX.DRE..LHE,
# 			OX.DRE..VHZ, OX.DRE..VHN, OX.DRE..VHE, OX.FUSE..BHZ, OX.FUSE..BHN,
# 			OX.FUSE..BHE, OX.FUSE..HHZ, OX.FUSE..HHN, OX.FUSE..HHE,
# 			OX.FUSE..HNZ, OX.FUSE..HNN, OX.FUSE..HNE, OX.FUSE..LHZ,
# 			OX.FUSE..LHN, OX.FUSE..LHE, OX.FUSE..VHZ, OX.FUSE..VHN,
# 			OX.FUSE..VHE, OX.MARN..BHZ, OX.MARN..BHN, OX.MARN..BHE,
# 			OX.MARN..HHZ, OX.MARN..HHN, OX.MARN..HHE, OX.MARN..HNZ,
# 			OX.MARN..HNN, OX.MARN..HNE, OX.MARN..LHZ, OX.MARN..LHN,
# 			OX.MARN..LHE, OX.MARN..VHZ, OX.MARN..VHN, OX.MARN..VHE, OX.MLN..BHZ
# 			OX.MLN..BHN, OX.MLN..BHE, OX.MLN..HHZ, OX.MLN..HHN, OX.MLN..HHE,
# 			OX.MLN..HNZ, OX.MLN..HNN, OX.MLN..HNE, OX.MLN..LHZ, OX.MLN..LHN,
# 			OX.MLN..LHE, OX.MLN..VHZ, OX.MLN..VHN, OX.MLN..VHE, OX.MPRI..HHZ,
# 			OX.MPRI..HHN, OX.MPRI..HHE, OX.MPRI..HNZ, OX.MPRI..HNN,
# 			OX.MPRI..HNE, OX.PLRO..BHZ, OX.PLRO..BHN, OX.PLRO..BHE,
# 			OX.PLRO..HHZ, OX.PLRO..HHN, OX.PLRO..HHE, OX.PLRO..HNZ,
# 			OX.PLRO..HNN, OX.PLRO..HNE, OX.PLRO..LHZ, OX.PLRO..LHN,
# 			OX.PLRO..LHE, OX.PLRO..VHZ, OX.PLRO..VHN, OX.PLRO..VHE,
# 			OX.PRED..BHZ, OX.PRED..BHN, OX.PRED..BHE, OX.PRED..HHZ,
# 			OX.PRED..HHN, OX.PRED..HHE, OX.PRED..HNZ, OX.PRED..HNN,
# 			OX.PRED..HNE, OX.PRED..LHZ, OX.PRED..LHN, OX.PRED..LHE,
# 			OX.PRED..VHZ, OX.PRED..VHN, OX.PRED..VHE, OX.SABO..BHZ,
# 			OX.SABO..BHN, OX.SABO..BHE, OX.SABO..HHZ, OX.SABO..HHN,
# 			OX.SABO..HHE, OX.SABO..HNZ, OX.SABO..HNN, OX.SABO..HNE,
# 			OX.VARN..HHZ, OX.VARN..HHN, OX.VARN..HHE, OX.VARN..HNZ,
# 			OX.VARN..HNN, OX.VARN..HNE, OX.ZOU2..HHZ, OX.ZOU2..HHN,
# 			OX.ZOU2..HHE, OX.ZOU2..HNZ, OX.ZOU2..HNN, OX.ZOU2..HNE,
# 			RF.GEPF..HHZ, RF.GEPF..HHN, RF.GEPF..HHE, SI.ABSI..BHZ,
# 			SI.ABSI..BHN, SI.ABSI..BHE, SI.ABSI..HHZ, SI.ABSI..HHN,
# 			SI.ABSI..HHE, SI.ABSI..LHZ, SI.ABSI..LHN, SI.ABSI..LHE,
# 			SI.ABSI..VHZ, SI.ABSI..VHN, SI.ABSI..VHE, SI.BOSI..BHZ,
# 			SI.BOSI..BHN, SI.BOSI..BHE, SI.BOSI..HHZ, SI.BOSI..HHN,
# 			SI.BOSI..HHE, SI.BOSI..LHZ, SI.BOSI..LHN, SI.BOSI..LHE,
# 			SI.BOSI..VHZ, SI.BOSI..VHN, SI.BOSI..VHE, SI.KOSI..BHZ,
# 			SI.KOSI..BHN, SI.KOSI..BHE, SI.KOSI..HHZ, SI.KOSI..HHN,
# 			SI.KOSI..HHE, SI.KOSI..LHZ, SI.KOSI..LHN, SI.KOSI..LHE,
# 			SI.KOSI..VHZ, SI.KOSI..VHN, SI.KOSI..VHE, SI.LUSI..HHZ,
# 			SI.LUSI..HHN, SI.LUSI..HHE, SI.MOSI..BHZ, SI.MOSI..BHN,
# 			SI.MOSI..BHE, SI.MOSI..HHZ, SI.MOSI..HHN, SI.MOSI..HHE,
# 			XO.AM02..EHZ, XO.AM02..EHN, XO.AM02..EHE, XO.AM02..HNZ (3x),
# 			XO.AM02..HNN (3x), XO.AM02..HNE (3x), XO.AM03..EHZ, XO.AM03..EHN,
# 			XO.AM03..EHE, XO.AM03..HNZ, XO.AM03..HNN, XO.AM03..HNE,
# 			XO.AM04..EHZ, XO.AM04..EHN, XO.AM04..EHE, XO.AM04..HNZ,
# 			XO.AM04..HNN, XO.AM04..HNE, XO.AM05..EHZ, XO.AM05..EHN,
# 			XO.AM05..EHE, XO.AM05..HNZ, XO.AM05..HNN, XO.AM05..HNE,
# 			XO.CP01..EHZ, XO.CP01..EHN, XO.CP01..EHE, XO.CP01..HNZ,
# 			XO.CP01..HNN, XO.CP01..HNE, XO.CP02..EHZ, XO.CP02..EHN,
# 			XO.CP02..EHE, XO.CP02..HNZ, XO.CP02..HNN, XO.CP02..HNE,
# 			XO.CP04..EHZ, XO.CP04..EHN, XO.CP04..EHE, XO.CP05..EHZ,
# 			XO.CP05..EHN, XO.CP05..EHE, XO.CP05..HNZ, XO.CP05..HNN,
# 			XO.CP05..HNE, XO.CP06..EHZ, XO.CP06..EHN, XO.CP06..EHE,
# 			XO.CP06..HNZ, XO.CP06..HNN, XO.CP06..HNE, XO.CP07..EHZ,
# 			XO.CP07..EHN, XO.CP07..EHE, XO.CP07..HNZ, XO.CP07..HNN,
# 			XO.CP07..HNE, XO.CV01..EHZ, XO.CV01..EHN, XO.CV01..EHE,
# 			XO.CV01..HNZ, XO.CV01..HNN, XO.CV01..HNE, XO.CV02..EHZ,
# 			XO.CV02..EHN, XO.CV02..EHE, XO.CV02..HNZ, XO.CV02..HNN,
# 			XO.CV02..HNE, XO.CV03..EHZ, XO.CV03..EHN, XO.CV03..EHE,
# 			XO.CV03..HNZ, XO.CV03..HNN, XO.CV03..HNE, XO.CV04..EHZ,
# 			XO.CV04..EHN, XO.CV04..EHE, XO.CV04..HNZ, XO.CV04..HNN,
# 			XO.CV04..HNE, XO.CV05..EHZ, XO.CV05..EHN, XO.CV05..EHE,
# 			XO.CV05..HNZ, XO.CV05..HNN, XO.CV05..HNE, XO.MB01..EHZ,
# 			XO.MB01..EHN, XO.MB01..EHE, XO.MB01..HNZ, XO.MB01..HNN,
# 			XO.MB01..HNE, XO.MB02..EHZ, XO.MB02..EHN, XO.MB02..EHE,
# 			XO.MB02..HNZ, XO.MB02..HNN, XO.MB02..HNE, XO.MB03..EHZ,
# 			XO.MB03..EHN, XO.MB03..EHE, XO.MB04..EHZ, XO.MB04..EHN,
# 			XO.MB04..EHE, XO.MB05..EHZ, XO.MB05..EHN, XO.MB05..EHE,
# 			XO.MB05..HNZ, XO.MB05..HNN, XO.MB05..HNE, XO.MB06..EHZ,
# 			XO.MB06..EHN, XO.MB06..EHE, XO.MB06..HNZ, XO.MB06..HNN,
# 			XO.MB06..HNE, XO.MB07..EHZ, XO.MB07..EHN, XO.MB07..EHE,
# 			XO.MB07..HNZ, XO.MB07..HNN, XO.MB07..HNE, XO.MB08..EHZ,
# 			XO.MB08..EHN, XO.MB08..EHE, XO.MB09..EHZ, XO.MB09..EHN,
# 			XO.MB09..EHE, XO.MB09..HNZ, XO.MB09..HNN, XO.MB09..HNE,
# 			XO.MB10..EHZ, XO.MB10..EHN, XO.MB10..EHE, XO.MB10..HNZ,
# 			XO.MB10..HNN, XO.MB10..HNE, XO.MB12..EHZ, XO.MB12..EHN,
# 			XO.MB12..EHE, XO.MB12..HNZ, XO.MB12..HNN, XO.MB12..HNE,
# 			XO.MN02..EHZ (2x), XO.MN02..EHN (2x), XO.MN02..EHE (2x),
# 			XO.MN02..HNZ (2x), XO.MN02..HNN (2x), XO.MN02..HNE (2x),
# 			XO.MN03..EHZ (2x), XO.MN03..EHN (2x), XO.MN03..EHE (2x),
# 			XO.MN03..HNZ, XO.MN03..HNN, XO.MN03..HNE, XO.MN04..EHZ,
# 			XO.MN04..EHN, XO.MN04..EHE, XO.MN04..HNZ, XO.MN04..HNN,
# 			XO.MN04..HNE, XO.MN06..EHZ (2x), XO.MN06..EHN (2x),
# 			XO.MN06..EHE (2x), XO.MN06..HNZ (2x), XO.MN06..HNN (2x),
# 			XO.MN06..HNE (2x), XO.MN08..EHZ, XO.MN08..EHN, XO.MN08..EHE,
# 			XO.MN08..HNZ, XO.MN08..HNN, XO.MN08..HNE, XO.MN09..EHZ,
# 			XO.MN09..EHN, XO.MN09..EHE, XO.MN09..HNZ, XO.MN09..HNN,
# 			XO.MN09..HNE, XO.SGF1..EHZ, XO.SGF1..EHN, XO.SGF1..EHE,
# 			XO.SGF2..EHZ, XO.SGF2..EHN, XO.SGF2..EHE, XO.SGF3..EHZ,
# 			XO.SGF3..EHN, XO.SGF3..EHE, XO.SGF3..HNZ, XO.SGF3..HNN,
# 			XO.SGF3..HNE, XO.SGF5..EHZ, XO.SGF5..EHN, XO.SGF5..EHE,
# 			XO.SGF6..EHZ, XO.SGF6..EHN, XO.SGF6..EHE, XO.SGF7..EHZ,
# 			XO.SGF7..EHN, XO.SGF7..EHE, XO.SGFR..EHZ, XO.SGFR..EHN,
# 			XO.SGFR..EHE, Z3.A300A..HHZ, Z3.A300A..HHN, Z3.A300A..HHE,
# 			Z3.A301A..HHZ, Z3.A301A..HHN, Z3.A301A..HHE, Z3.A302A..HHZ,
# 			Z3.A302A..HHN, Z3.A302A..HHE, Z3.A303A..HHZ, Z3.A303A..HHN,
# 			Z3.A303A..HHE, Z3.A304A..HHZ, Z3.A304A..HHN, Z3.A304A..HHE,
# 			Z3.A305A..HHZ, Z3.A305A..HHN, Z3.A305A..HHE, Z3.A306A..HHZ,
# 			Z3.A306A..HHN, Z3.A306A..HHE, Z3.A307A..HHZ, Z3.A307A..HHN,
# 			Z3.A307A..HHE, Z3.A308A..HHZ, Z3.A308A..HHN, Z3.A308A..HHE,
# 			Z3.A309A..HHZ, Z3.A309A..HHN, Z3.A309A..HHE, Z3.A312A..HHZ,
# 			Z3.A312A..HHN, Z3.A312A..HHE, Z3.A313A..HHZ, Z3.A313A..HHN,
# 			Z3.A313A..HHE, Z3.A316A..HHZ, Z3.A316A..HHN, Z3.A316A..HHE,
# 			Z3.A317A..HHZ, Z3.A317A..HHN, Z3.A317A..HHE, Z3.A318A..HHZ,
# 			Z3.A318A..HHN, Z3.A318A..HHE, Z3.A319A..HHZ, Z3.A319A..HHN,
# 			Z3.A319A..HHE

# %% [markdown]
# ```{div} full-width
# Here, we print a summary of the main information of each seismic network, as the description and the starting and ending dates
# ```

# %%
for network in inventory:
    
    start = str(network.start_date.date)

    if network.end_date is None: end = "present" 
    else: end = str(network.end_date.date)
    
    print("Network code: {0:2}   Period: {1:10} to {2:10}   Description: {3:60}   ".format(network.code,start,end,network.description))
# Out:
# Network code: 3A   Period: 2016-09-19 to 2016-11-30   Description: Seismic Microzonation Network, 2016 Central Italy
# Network code: 5J   Period: 2014-07-16 to 2016-09-27   Description: The Sardinia Passive Array experiment
# Network code: 7C   Period: 2021-01-01 to 2031-12-31   Description: Urban Seismic Network (RUSN-CAL-INGV)
# Network code: AC   Period: 2002-01-01 to present      Description: Albanian Seismic Network
# Network code: BA   Period: 2005-01-01 to present      Description: Universita della Basilicata Seismic Network
# Network code: GU   Period: 1980-01-01 to present      Description: Regional Seismic Network of North Western Italy
# Network code: IV   Period: 1988-01-01 to present      Description: Italian Seismic Network
# Network code: IX   Period: 2005-01-01 to present      Description: Irpinia Seismic Network, Italy
# Network code: MN   Period: 1988-01-01 to present      Description: Mediterranean Very Broadband Seismographic Network
# Network code: NI   Period: 2002-01-01 to present      Description: North-East Italy Broadband Network
# Network code: OT   Period: 2013-04-01 to present      Description: OTRIONS Local Seismic Network, Apulia, Italy
# Network code: OX   Period: 2016-01-01 to present      Description: North-East Italy Seismic Network
# Network code: RF   Period: 1993-01-01 to present      Description: Friuli Venezia Giulia Accelerometric Network, Italy
# Network code: SI   Period: 2006-01-01 to present      Description: Sudtirol Network, Italy
# Network code: ST   Period: 1981-01-01 to present      Description: Trentino Seismic Network, Italy
# Network code: TV   Period: 2008-01-01 to present      Description: INGV Experiments Network
# Network code: XO   Period: 2016-08-24 to 2017-11-07   Description: EMERSITO Seismic Network, 2016 Central Italy
# Network code: Z3   Period: 2015-01-01 to 2022-12-31   Description: AlpArray Seismic Network (AASN) temporary component

# %% [markdown]
# ### Seismic stations

# %%
network_code, station_code = "IV", "MRLC"
glue("station",network_code+"."+station_code)
# Out:
# 'IV.MRLC'

# %% [markdown]
# ```{div} full-width
# Let us define the network and station codes of the seismic station {glue:}`station` that we will use as case study in this lecture
# ```

# %%
network_code, station_code = "IV", "MRLC"

# %% [markdown]
# ```{div} full-width
#
# and select it from the `inventory`
#
# ```

# %%
inv = inventory.select(network_code, station_code, time=origin.time)
print("INVENTORY:\n\n",inv)

station = inv[0][0]
print("\nSTATION:\n\n",station)
# Out:
# INVENTORY:
#
#  Inventory created at 2023-02-22T05:57:32.927000Z
# 	Created by: INGV-ONT WEB SERVICE: fdsnws-station | version: 1.1.54
# 		    /exist/apps/fdsn-station/fdsnws/station/1/query?starttime=2016-01-...
# 	Sending institution: eXistDB (INGV-ONT)
# 	Contains:
# 		Networks (1):
# 			IV
# 		Stations (1):
# 			IV.MRLC (Muro Lucano)
# 		Channels (15):
# 			IV.MRLC..BHZ, IV.MRLC..BHN, IV.MRLC..BHE, IV.MRLC..HHZ,
# 			IV.MRLC..HHN, IV.MRLC..HHE, IV.MRLC..HNZ, IV.MRLC..HNN,
# 			IV.MRLC..HNE, IV.MRLC..LHZ, IV.MRLC..LHN, IV.MRLC..LHE,
# 			IV.MRLC..VHZ, IV.MRLC..VHN, IV.MRLC..VHE
#
# STATION:
#
#  Station MRLC (Muro Lucano)
# 	Station Code: MRLC
# 	Channel Count: 18/24 (Selected/Total)
# 	2003-03-01T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m
# 	Available Channels:
# 	    ..HN[ZNE]   100.0 Hz  2011-08-08 to 2017-04-10
# 	    ..HH[ZNE]   100.0 Hz  2005-03-23 to None
# 	    ..BH[ZNE]    20.0 Hz  2005-03-23 to None
# 	    ..LH[ZNE]     1.0 Hz  2005-03-23 to None
# 	    ..VH[ZNE]     0.1 Hz  2005-03-23 to None

# %% [markdown]
# ```{div} full-width
# As we can see, the seismic station hosts 5 different kinds of channels: HN*, HH*, BN*, LH* and VH*. The first and second letters indicates the band and instrument codes, while third letter indicates the orientation code that, in the present case, can be vertical (Z), north (N) and east (E). We can visit the web page  [SEED Channel Naming](https://ds.iris.edu/ds/nodes/dmc/data/formats/seed-channel-naming/) for a detailed description of the different band, instrument and orientation codes.
#
# For now, let us give a look to all the channels of the seismic station
# ```

# %%
for channel in station:
    print("\nCHANNEL\n\n",channel)
# Out:
# CHANNEL
#
#  Channel 'BHE', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 20.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'BHN', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 20.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'BHZ', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Sampling Rate: 20.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HHE', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HHN', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HHZ', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HNE', Location ''
# 	Time range: 2011-08-08T17:54:00.000000Z - 2017-04-10T17:54:00.000000Z
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HNN', Location ''
# 	Time range: 2011-08-08T17:54:00.000000Z - 2017-04-10T17:54:00.000000Z
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP)
# 	Response information available
#
# CHANNEL
#
#  Channel 'HNZ', Location ''
# 	Time range: 2011-08-08T17:54:00.000000Z - 2017-04-10T17:54:00.000000Z
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP)
# 	Response information available
#
# CHANNEL
#
#  Channel 'LHE', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 1.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'LHN', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 1.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'LHZ', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Sampling Rate: 1.00 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'VHE', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 0.10 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'VHN', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 0.10 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available
#
# CHANNEL
#
#  Channel 'VHZ', Location ''
# 	Time range: 2005-03-23T17:54:00.000000Z - --
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Sampling Rate: 0.10 Hz
# 	Sensor (Description): None (NANOMETRICS TRILLIUM-40S)
# 	Response information available

# %% [markdown]
# ```{div} full-width
# and select some relevant information, like the sampling rate, the input and output units, and the kind of sensor associated to each channel
# ```

# %%
for channel in station:
    
    code          = channel.code
    sampling_rate = channel.sample_rate
    sensor        = channel.sensor.description
    
    response = channel.response
    
    input_units  = response.instrument_sensitivity.input_units
    output_units = response.instrument_sensitivity.output_units
    
    text = r'{0:5}   sampling rate = {1:5.1f} [Hz]   input = {2:7}   output = {3:7}  {4:25}'.format(code,sampling_rate,input_units,output_units,sensor)
    print(text)
# Out:
# BHE     sampling rate =  20.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# BHN     sampling rate =  20.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# BHZ     sampling rate =  20.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# HHE     sampling rate = 100.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# HHN     sampling rate = 100.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# HHZ     sampling rate = 100.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# HNE     sampling rate = 100.0 [Hz]   input = M/S**2    output = COUNTS   KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP
# HNN     sampling rate = 100.0 [Hz]   input = M/S**2    output = COUNTS   KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP
# HNZ     sampling rate = 100.0 [Hz]   input = M/S**2    output = COUNTS   KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP
# LHE     sampling rate =   1.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# LHN     sampling rate =   1.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# LHZ     sampling rate =   1.0 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# VHE     sampling rate =   0.1 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# VHN     sampling rate =   0.1 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S
# VHZ     sampling rate =   0.1 [Hz]   input = M/S       output = COUNTS   NANOMETRICS TRILLIUM-40S

# %% [markdown]
# ```{div} full-width
#
# From this list, we can learn that all the channels convert the ground velocity (m/s) into integers (counts), but for the channels HN* which instead convert the ground acceleration (m/s$^2$) into integers (counts). We thus understand that the instrument codes H and N (the second letter) stand for velocimeters (or high gain seismometer, NANOMETRICS TRILLIUM-40S) and accelerometers (KINEMETRICS EPISENSOR-FBA-ES-T-CL-1G-FS-40-VPP), respectively.
#
# As it concerns the channels of the velocimeters, we can see that they are characterized by different band codes (B,H,L,V), each of which with different sampling rates. These channels comes from the same sensor (NANOMETRICS TRILLIUM-40S) and they are provided for different purposes, depending on the frequency range on which we are interested. For seismological applications, we shall select the chahnels with the highest sampling rate that, for this velocimeters, are the channels HH*.
#
# In {numref}`Section %s - Seismometers <sec-seismometer>` we will better discuss how modern seismometers work and why they record *counts* rather than the relative motion as discussed in {numref}`Lecture %s - Harmonic oscillator <chap-H>`.
# ```

# %% [markdown]
# ### Seismic channels

# %% [markdown]
# ```{div} full-width
#
# In order to dispose of an `inventory` with only the channels with the highest sampling rates, we make use of the function `lab.keep_seismic_channels` which, for each instrument codes, select the band code with the highest sampling rate
#
# ```

# %%
import lab

inventory = lab.keep_seismic_channels(inventory)
file = directory+"Seismic_Inventory.xml"
inventory.write(file,format="STATIONXML")

# %% [markdown]
# ```{div} full-width
#
# As you can see now, the seismic station {glue:}`station` only contains the HH* and HN* channels
#
# ```

# %%
inv = inventory.select(network_code, station_code, time=origin.time)
station = inv[0][0]
print("STATION:\n\n",station)
# Out:
# STATION:
#
#  Station MRLC (Muro Lucano)
# 	Station Code: MRLC
# 	Channel Count: 18/24 (Selected/Total)
# 	2003-03-01T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 40.7564, Longitude: 15.4889, Elevation: 605.0 m
# 	Available Channels:
# 	    ..HN[ZNE]   100.0 Hz  2011-08-08 to 2017-04-10
# 	    ..HH[ZNE]   100.0 Hz  2005-03-23 to None

# %% [markdown]
# (sec-seismometer)=
# ## Seismometers
#
# ```{div} full-width
# A seismic station (or seismograph) consists of a sensor (seismometer),
# an analog to digital converter (digitizer) and the recorder. The
# seismometer converts the ground motion (input) into another continuous
# physical signal, like a voltage (or the motion of the stylos drawing on
# a sheet of paper). The digitizer converts the output signal from the
# sensor into a number called *count*, just like we do with a digital voltmeter.
# The digitizer is characterized by the resolution (how we discretize the
# continuous voltage into *counts*) and the sampling rate
# (how many *counts* per second). In the end, the recorder stores the
# *counts* from the ditigitizer into flash memories or hard disks.
#
# Sensors are divided into passive and active sensors. A (modern) passive
# seismometer mainly consists of a spring-mass system and a coil embedded
# into a magnetic field that both damps the motion of the mass with
# respect to the seismometer and outputs a voltage which is nearly
# proportional to the ground velocity above the natural frequency of the
# spring-mass system (typically of the order of 1 Hz, although it
# can be as low as 0.03 Hz). It thus can be seen as a velocity
# transducer. Older passive seismometers, instead, simply consist of a
# spring-mass system in series with a dash pot (usually filled with oil)
# and measure the displacement of the mass through a stylus drawing on a
# sheet of paper or some other optical devices. An active seismometer, like the
# force balanced accelerometers (FBA), adds a displacement transducer
# (i.e., a capacitor whose capacitance varies with the displacement of the
# mass) that sends, in a negative feedback loop, a current to the coil
# which exerts a force equal and opposite to the inertia force in order to
# prevent the mass from moving at all with respect to the seismometer.
# This current, being proportional to the ground acceleration in a large
# frequency band, gives a direct measure of it.
#
# Passive seismometers, although less accurate than the active ones, are
# cheaper and simpler to be installed into the field.
#
# ```
#
# ### Velocimeters
#
# ```{div} full-width
# A modern passive seismometer (or digital velocimeter) can be obtained using a mechanical seismometer and converting
# the relative motion of the mass into a current through a magnetic field and a coil.
# This current can also be used to damp the relative motion of the mass. In this case, the output
# of the seismometer is a voltage, $V$, proportional to the relative velocity
# of the mass with respect to the seismometer, $\dot{z}$,
#
# $$
# \begin{align}
# &V(t) = G\,\dot{z}(t)
# \end{align}
# $$
#
# with $G$ being the generator constant.
# The voltage is then converted into $n$ bits (typically 24), or counts, by the
# digitizer and stored into the recorder
#
# $$
# \begin{align}
# & c(t) = C\,V(t)
# \end{align}
# $$
#
# The digitizer has $2^n$ ($\approx 1.7\times10^{7}$) levels that, once
# subdivided into positive and negatives levels, correspond to a dynamic
# range from $-2^{n-1}$ to $2^{n-1}-1$
# ($\approx \pm 8.4\times10^{6}$). In this respect, assuming a voltage range $[-V_\mathrm{max},V_\mathrm{max}]$, the constant $C$ reads
#
#
# $$
# \begin{align}
# & C = \frac{2^{n-1}}{V_\mathrm{max}}
# \end{align}
# $$
#
# Depending on the generatot constant and on the voltage range of the voltmeter, a modern passive seismometer can be subdivides into high and low gain seismometers. High gain seismometers finely discretize a small voltage ranges, thus being accurate but prone to saturation. Low-gain seismometers, instead, are set in such a way that the voltage ranges is wide and, so, they hardly reach the saturation but they are less accurate than high-gain seismometers. The latter are use for strong ground motion applications, i.e., for studying seismic waves in proximity of the epicenter. High-gain seismometers, instead, can be used to studying teleseismic waves, far from the epicenter.
#
# By considering the response function, as defined in  {numref}`Lecture %s <chap-H>` - {ref}`chap-H` and  {numref}`Lecture %s <chap-F>` - {ref}`chap-F`, and the fact that the output of the velocimeters is in counts, we can write the following relation between the Fourier transform of the counts and the ground velocity
#
# $$
# \begin{align}
# \tilde{c}(\omega) = C\,G\,\big(i\,\omega\,\tilde{z}(\omega)\big) = C\,G\,\tilde{R}(\omega)\,(i\,\omega\,\tilde{u}_g(\omega)\big)
# \end{align}
# $$
#
# In this respect, the response function of seismometers differs by that of an harmonic oscillator only by the factor $C\,G$, that is the so called *instrument sensitivity*.
#
# ```

# %% [markdown]
# ### Response function
#
# ```{div} full-width
# Let us consider the east channel of the velocimeter (HHE) of the seismic station {glue:}`station`
# ```

# %%
channel = station.select(channel="HHE")[0]

# %% [markdown]
# ```{div} full-width
# and investigate its field `response`
# ```

# %%
response = channel.response
print(response)
# Out:
# Channel Response
# 	From M/S () to COUNTS ()
# 	Overall Sensitivity: 1.5e+09 defined at 0.200 Hz
# 	5 stages:
# 		Stage 1: PolesZerosResponseStage from M/S to V, gain: 1500
# 		Stage 2: CoefficientsTypeResponseStage from V to COUNTS, gain: 1e+06
# 		Stage 3: CoefficientsTypeResponseStage from COUNTS to COUNTS, gain: 1
# 		Stage 4: CoefficientsTypeResponseStage from COUNTS to COUNTS, gain: 1
# 		Stage 5: CoefficientsTypeResponseStage from COUNTS to COUNTS, gain: 1

# %% [markdown]
# ```{div} full-width
# As we can see, the `response` consists of $5$ stages. The first and second stages describe the actual sensor which converts the ground velocity into a voltage and the digitizer which converts the voltage into counts. The following stages, instead, are digital processings by means of which the counts are organized to be properly recorded
# ```

# %%
for response_stage in response.response_stages:
    print("\nRESPONSE STAGE:\n\n",response_stage)
# Out:
# RESPONSE STAGE:
#
#  Response type: PolesZerosResponseStage, Stage Sequence Number: 1
# 	From M/S to V
# 	Stage gain: 1500.0, defined at 0.20 Hz
# 	Transfer function type: LAPLACE (RADIANS/SECOND)
# 	Normalization factor: 98696, Normalization frequency: 0.20 Hz
# 	Poles: (-0.1111+0.1111j), (-0.1111-0.1111j), (-172.79+262.37j), (-172.79-262.37j)
# 	Zeros: 0j, 0j
#
# RESPONSE STAGE:
#
#  Response type: CoefficientsTypeResponseStage, Stage Sequence Number: 2
# 	From V to COUNTS
# 	Stage gain: 1000000.0, defined at 0.00 Hz
# 	Decimation:
# 		Input Sample Rate: 30000.00 Hz
# 		Decimation Factor: 1
# 		Decimation Offset: 0
# 		Decimation Delay: 0.00
# 		Decimation Correction: 0.00
# 	Transfer function type: DIGITAL
# 	Contains 0 numerators and 0 denominators
#
# RESPONSE STAGE:
#
#  Response type: CoefficientsTypeResponseStage, Stage Sequence Number: 3
# 	From COUNTS to COUNTS
# 	Stage gain: 1.0, defined at 1.00 Hz
# 	Decimation:
# 		Input Sample Rate: 30000.00 Hz
# 		Decimation Factor: 15
# 		Decimation Offset: 0
# 		Decimation Delay: 0.00
# 		Decimation Correction: -0.00
# 	Transfer function type: DIGITAL
# 	Contains 165 numerators and 0 denominators
#
# RESPONSE STAGE:
#
#  Response type: CoefficientsTypeResponseStage, Stage Sequence Number: 4
# 	From COUNTS to COUNTS
# 	Stage gain: 1.0, defined at 1.00 Hz
# 	Decimation:
# 		Input Sample Rate: 2000.00 Hz
# 		Decimation Factor: 10
# 		Decimation Offset: 0
# 		Decimation Delay: 0.00
# 		Decimation Correction: -0.05
# 	Transfer function type: DIGITAL
# 	Contains 187 numerators and 0 denominators
#
# RESPONSE STAGE:
#
#  Response type: CoefficientsTypeResponseStage, Stage Sequence Number: 5
# 	From COUNTS to COUNTS
# 	Stage gain: 1.0, defined at 1.00 Hz
# 	Decimation:
# 		Input Sample Rate: 200.00 Hz
# 		Decimation Factor: 2
# 		Decimation Offset: 0
# 		Decimation Delay: 0.00
# 		Decimation Correction: -0.56
# 	Transfer function type: DIGITAL
# 	Contains 223 numerators and 0 denominators

# %% [markdown]
# ```{div} full-width
# By using the method `response.plot` we can give a first look to the Fourier transform of the response function
# ```

# %%
fig,axes= plt.subplots(2, tight_layout=True, sharex=True)
fig = response.plot(0.001, output="DEF", axes=list(axes))

# %% [markdown]
# ```{div} full-width
# By using the method `response.get_evalresp_response`, instead, we can evaluate the Fourier transform of the response function at the discrete frequency corresponding to a sampling time interval $[0,T)$ and step $d$
# ```

# %%
T, d = 1e3, 1e-2
n = int(T/d)

Rs, fs = response.get_evalresp_response(d, n, output="DEF")

print("Frequencies:",fs)
print("Responses: ",Rs)
# Out:
# Frequencies: [0.e+00 1.e-03 2.e-03 ... 5.e+01 5.e+01 5.e+01]
# Responses:  [ 0.000e+00+0.000e+00j -2.395e+06+1.357e+05j -9.534e+06+1.086e+06j ...
#   5.720e-02-7.478e+01j  5.456e-02-7.489e+01j  5.192e-02-7.501e+01j]

# %% [markdown]
# ```{div} full-width
# and plot it by ourselves
# ```

# %%
fig,axes = plt.subplots(2, 1, tight_layout=True, sharex=True, figsize=(5,6))
lab.plot_spectrum(fs, Rs, axes)

# %% [markdown]
# ```{div} full-width
# Here below we show the response functions relating the counts to the ground displacement, velocity and acceleration
# ```

# %%
fig,axes = plt.subplots(2,3,tight_layout=True,sharex=True,figsize=(12,6))
for axe,output in zip(axes.T,["DISP","VEL","ACC"]):
    Rs, fs = response.get_evalresp_response(d,n,output=output)
    ylabel = output=="DISP"
    lab.plot_spectrum(fs, Rs, axe, ylabel=ylabel)
    axe[0].set_title(output)

# %% [markdown]
# ```{div} full-width
# We can also remove the last stage to the response function for understaning the impact of it
# ```

# %%
end_stage = len(response.response_stages) - 1
fig,axes = plt.subplots(2,3,tight_layout=True,sharex=True,figsize=(12,6))
for axe,output in zip(axes.T,["DISP","VEL","ACC"]):
    Rs, fs = response.get_evalresp_response(d,n,output=output,end_stage=end_stage)
    lab.plot_spectrum(fs,Rs,axe)
    axe[0].set_title(output)

# %% [markdown]
# <p style="page-break-after:always;"></p>
