# %% [markdown]
# (chap-L3)=
# # Earthquake localization
#
# ```{contents} Sections
# :local:
# :depth: 2
# ```
#
# ```{div} full-width
#
# In this lesson, we will locate the origin of the 24/8/2016 M=6 Accumoli earthquake by exploiting the pickings of the first arrivals of the P and S waves obtained from the waveforms meeasured by a set of seismic station in the surrouning of the earthquake. In particular, our goal is to estimate the origin time, longitude, latitude and depth of the earthquake and to estimate the uncertainty of these estimates as well.
#
# In doing it, we will need a velocity model in order to modelling the several paths of the P and S waves from the hypocenter to the seismic stations and quantify the travel times. In particular, we will adopt the same velocity model used by the Istituto Nazionale di Geofisica e Vulcanologia for locating most of the earthquakes occurred in Italy. It is composed by the upper and lower crusts and the lithospheric mantle. The Conrad (between the upper and lower crusts) and Moho (between the lower crust and the lithospheric mantle) are set at 11 and 26.9 km depth.
#
# ```

# %% [markdown]
# ## Inverse problem theory
#
# ```{div} full-width
#
# We now rewiev the minimal aspects ot the inverse problem thoery that we need for estimating the origin time and spatial coordinates of an earthquake. More details about this topic can be found in {numref}`Appendix %s - Inverse problem theory <chap-I>`, including the difference between volumetric and density probability functions and how taking into account modelling errors.
#
# ```
#
# ### Observation equation
#
# ```{div} full-width
#
# Let us write the so called observation equation
#
# $$
# \begin{align}
# & y = f(m) + \varepsilon
# \end{align}
# $$ (E:1)
#
# where $f$ is the function expressing the theoretical relationship between the model parameters $m$ and the observations $y$, and $\varepsilon$ are the random errors that we assume to obey to a (N-dimensional) Gaussian distribution with zero mean and covariance $\mathrm{C}$
#
# $$
# \begin{align}
# & p(\varepsilon) = \frac{1}{\sqrt{(2\,\pi)^N\,\det(C)}}\,\exp\left(-\frac{\varepsilon^T\,C^{-1}\,\varepsilon}{2}\right)
# \end{align}
# $$ (E:2)
#
# In particular, $y$, $\varepsilon$ and $m$ are the arrays collecting the $N$ observations $y_i$, the $N$ random errors $\varepsilon_i$ and the $M$ model parameters $m_i$
#
# $$
# \begin{align}
# & y = \big(y_1,\cdots,y_N\big) \qquad \varepsilon = \big(\varepsilon_1,\cdots,\varepsilon_N\big) \qquad m =(m_1,\cdots,m_M)
# \end{align}
# $$ (E:3)
#
# Just because $\varepsilon=y-f(m)$, we can see eq. {eq}`E:2` as the conditional probability denstity function (PDF) for the observations given the model parameters
#
# $$
# \begin{align}
# & p(y|m) = \frac{1}{\sqrt{(2\,\pi)^N\,\det(C)}}\,\exp\left(-\frac{W(m)}{2}\right)
# \end{align}
# $$ (E:4)
#
# with $W$ being the so called weighted residual square sum (WRSS)
#
# $$
# \begin{align}
# & W(m) = (y-f(m))^T\,C^{-1}\,(y-f(m))
# \end{align}
# $$ (E:5)
#
# ```
#
#
# <font size="4"> Homogeneous half-space model </font>
#
# ```{div} full-width
#
# Let us now consider the simple half-space homogeneous Earth models and denote with $c_p$ and $c_s$ being the velocities of the P and S waves, respectively, and the model parameters $m$ as the origin time $t_e$ and spatial coordinates $\mathbf{x}_e$
#
# $$
# \begin{align}
# & m=(t_e,\mathbf{x}_e)
# \end{align}
# $$ (E:6)
#
# In this case, the observation equation {eq}`E:1` can be further specified as follows
#
# $$
# \begin{align}
# & y_i = f_i(m) + \varepsilon_i  \qquad
# \end{align}
# $$ (E:7)
#
# with
#
# $$
# \begin{align}
# & f_i(m) =  t_e + \frac{|\mathbf{x}_i-\mathbf{x}_e|}{c_i}
# \end{align}
# $$ (E:8)
#
# Here, $y_i$ and $\varepsilon_i$ are the time and the random error of the $i$-th pickings, while $c_i$ and $\mathbf{x}_j$ are  the seismic velocity of its phase ($c_p$ or $c_s$) and the spatial coordinates of its seismic station. Furthermore, assuming that there are no modelling errors and that the observations are independent, the covariance $C$ of the random errors is a simple diagonal matrix
#
# $$
# \begin{align}
# & C = \mathrm{diag}(\sigma_1^2,\cdots,\sigma_N^2)
# \end{align}
# $$ (E:9)
#
# with the variances $\sigma_i^2$ as diagonal elements. Here, $\sigma_i$ is the standard deviation of the $i$-th picking.
#
# We note that, in this simple case, the inverse of the covariance $C $ simply reads
#
# $$
# \begin{align}
# & C ^{-1} = \mathrm{diag}(\sigma_1^{-2},\cdots,\sigma_N^{-2})
# \end{align}
# $$ (E:10)
#
# and the WRSS, eq. {eq}`E:5` simplifies into
#
# $$
# \begin{align}
# & W(m) = \sum_{i=1}^N \left(\frac{y_i-f_i(m)}{\sigma_i}\right)^2
# \end{align}
# $$ (E:11)
#
# Recasted in this form, we can understand that each term of the summation defining the WRSS is the residual square $(y_i-f_i(m))^2$ weighted by the variance $\sigma_i^2$.
#
# ```
#
# ### Posterior probability density function (PDF)
#
# ```{div} full-width
#
# The posterior PDF is the conditional PDF $p(m|y)$ of the model parameters given the observaions. In order to obtain the posterior PDF, let us now assume that the prior information on the model parameters are described by the PDF $p(m)$ and make use of it for defining the PDF for both the observations and the model parameters
#
# $$
# \begin{align}
# & p(y,m) = p(y|m)\,p(m)
# \end{align}
# $$ (E:12)
#
# In this respect the prior information can be seen as the marginal PDF for the model parameters
#
# $$
# \begin{align}
# & p(m) =\int_{\mathbb{R}^N} p(y,m)\,d y = p(m)\,\int_{\mathbb{R}^N} p(y|m)\,d y  = p(m)
# \end{align}
# $$ (E:13)
#
# In order to obtain the posterior PDF $p(m|y)$, we rewrite eq. {eq}`E:12` with the roles of $y$ and $m$ reversed
#
# $$
# \begin{align}
# & p(y,m) = p(m|y)\,p(y)
# \end{align}
# $$ (E:14)
#
# with $p(y)$ being the marginal PDF for the observation
#
# $$
# \begin{align}
# & p(y) = \int_{\mathcal{M}} p(y,m)\,dm
# \end{align}
# $$ (E:15)
#
# where $\mathcal{M}\subseteq\mathbb{R}^M$ is the model parameter space. The latter can be a subset of the M-dimensional space just because some model parameters can be constrained to some sepcific region of it, as for instance the vertical (or radial) coordinate of the origin that we assume to be non-positive (i.e., we will consider only positive depth, within the solid Earth).
#
# From the comparison between eqs. {eq}`E:12` and {eq}`E:14`, we thus obtain the so called Bayes' theorem
#
# $$
# \begin{align}
# & p(m|y) = \frac{p(y|m)\,p(m)}{p(y)}
# \end{align}
# $$ (E:16)
#
# We note that the denominator $p(y)$ of the right-hand side of eq. {eq}`E:16` is needed only for normalizing the posterior PDF and, so, we can write
#
# $$
# \begin{align}
# & p(m|y) \propto p(y|m)\,p(m)
# \end{align}
# $$ (E:17)
#
# Further assuming that we do not have prior information and that the prior PDF is constant, the Bayes' theorem simply states that the posterior PDF is simply proportional to the conditional PDF of the observations given the model parameters
#
# $$
# \begin{align}
# & p(m|y) \propto p(y|m)
# \end{align}
# $$ (E:18)
#
# ```
#
# ### Additional weights
#
# ```{div} full-width
#
# As we will see, the pickings from the Istituto Nazionale di Geofisica e Vulcanologia are provided with both the uncertainties (i.e., their standard derivations $\sigma_i$) and additional weights $w_i$. This means that the WRSS, eq. {eq}`E:11` is actualy modified as follows
#
# $$
# \begin{align}
# & \displaystyle
# W(m) = \sum_{i=1}^N w_i\,\left(\frac{y_i-f_i(m)}{\sigma_i}\right)^2
# \end{align}
# $$ (E:19)
#
# where each weighted residual square is multiplied by the additional weight $w_i$. The use of additional weight is quite common in the earthquake localization because it allows to give more weights to the early pickings (i.e., to the pickings of those seismic stations closer to the earthquake origin). It easy to understand that their introduction is equivalent to scale the original standard deviations $\sigma_i$ by $w_i^{-1/2}$
#
# $$
# \begin{align}
# & \displaystyle
# W(m) = \sum_{i=1}^N \left(\frac{y_i-f_i(m)}{\sigma_i\,w_i^{-1/2}}\right)^2
# \end{align}
# $$ (E:20)
#
# In light of this and of eqs. {eq}`E:4` and {eq}`E:18`, we thus obtain
#
# $$
# \begin{align}
# & p(m|y) = k\,\exp\left(-\frac{W(m)}{2}\right)
# \end{align}
# $$ (E:21)
#
# where $k$ is a normalization constant that we will not need to determine.
#
# Neglecting the differences between volumetric and density probability functions discussed in {numref}`Appendix %s - Inverse problem theory <chap-I>`, we can estimate the best (or most likelihood) model parameters by minimizing thw WRSS. In other words, the model parameteres $m^*$ that minimize $W$ will be our estimate of the origin time and spatial coordinates of the earthquake
#
# $$
# \begin{align}
#  W(m^*) = \min_{m\in\mathcal{M}} W(m) &
# \end{align}
# $$ (E:22)
#
# ```

# %% [markdown]
# ## Data set
#
# ```{div} full-width
#
# In this section we will obtain all the information that we need to define the inverse problem, which means that we will obtain the picking times and all the additional information that we need for implementing the theoretical relationship between the model parameters and the observations, as well as calculating the WRSS.
#
# ```
#
# ### Earthquake selection
#
# ```{div} full-width
#
# Let us start by importing the main python libraries
#
# ```

# %%
# %matplotlib widget
import lab
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
from myst_nb import glue
np.set_printoptions(precision=3,suppress=True)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ```{div} full-width
#
# and reading the seismic inventory and the catalog containing only the 2016-08-24 M6 Accumuli earthquake that we downloaded in the  {numref}`Lecture %s <chap-L1>` {ref}`chap-L1`
#
# ```

# %%
from obspy.core.event import read_events
from obspy.core.inventory import read_inventory

directory = "Amatrice-Norcia-Visso/"

file = directory+"Seismic_Inventory.xml"
inventory = read_inventory(file)

file = directory + "7073641_Accumuli.xml"
catalog = read_events(file)

# %% [markdown]
# ```{div} full-width
#
# and we select the only event in the catalog
#
# ```

# %%
event = catalog[0]
print(event)
# Out:
# Event:	2016-08-24T01:36:32.000000Z | +42.698,  +13.233 | 6.0  Mw | manual
#
# 	                  resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=7073641")
# 	                   event_type: 'earthquake'
# 	                creation_info: CreationInfo(agency_id='INGV', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 52))
# 	          preferred_origin_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=31549261")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=7631")
# 	                         ---------
# 	           event_descriptions: 1 Elements
# 	                        picks: 699 Elements
# 	             focal_mechanisms: 2 Elements
# 	                      origins: 8 Elements
# 	                   magnitudes: 8 Elements

# %% [markdown]
# ```{div} full-width
#
# Giving a look to the picks, we can understand that each `pick` contains information like the waveform from which has been evalueted, the phase of seismic (P or S) waves considered, the time (in `UTCDateTime`) of its arrival at the seismic station and the author who performed the measurement
#
# ```

# %%
for pick in event.picks:
    print(pick)
# Out:
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140940591")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 34, 910000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SMA1', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 9, 36, 3))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140236691")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 36) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='NRCA', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133513991")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 36, 520000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='LNSS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 52))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234931")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 36, 540000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='LNSS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514011")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 36, 810000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='RM33', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234951")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 36, 840000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='RM33', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532331")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 37, 360000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='LNSS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234971")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 37, 810000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TERO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514941")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 37, 810000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TERO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532351")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 340000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TERO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532341")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 390000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='RM33', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140975911")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 720000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='LNSS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'S'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140924221")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 740000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FEMA', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 9, 4, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514041")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 860000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FEMA', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514061")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 38, 910000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GIGS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235011")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 310000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GIGS', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532361")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 310000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FEMA', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514081")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 330000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FDMO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514981")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 570000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='MN', station_code='AQU', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235021")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 580000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FDMO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235051")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 610000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='MN', station_code='AQU', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514101")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 720000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ARRO', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235041")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 780000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ARRO', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876761")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 39, 970000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GUMA', channel_code='HNN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 7, 46, 50))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140940611")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 100000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='RM33', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'S'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 9, 36, 3))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514121")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 130000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235071")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 150000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532421")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 290000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ARRO', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532431")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 580000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532441")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 930000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIAM', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133514141")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 930000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIAM', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 36, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515091")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 40, 980000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='OFFI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235091")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 60000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='OFFI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235101")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 240000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIAM', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532451")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 640000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='OFFI', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515181")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 660000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FAGN', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532461")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 660000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FAGN', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515121")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 750000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESX', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235121")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 41, 960000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESX', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235161")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 20000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FAGN', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515241")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 80000) [uncertainty=1.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TRTR', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235141")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 100000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MDAR', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235111")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 140000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MNTP', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515211")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 380000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MDAR', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532471")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 400000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='CESX', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532491")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 610000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MDAR', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515151")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 670000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MNTP', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532511")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 670000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MNTP', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515281")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 730000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ASSB', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235181")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 820000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SSM1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515261")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 870000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='VCEL', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532561")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 880000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SSM1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515301")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 880000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SSM1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140975921")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 42, 900000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TERO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'S'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235171")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 40000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ASSB', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235201")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 120000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIU1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515321")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 160000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIU1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876701")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 230000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TRTR', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 7, 46, 50))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532531")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 390000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='ASSB', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515341")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 420000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GAG1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235221")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 420000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='VCEL', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532591")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 420000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GAG1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235241")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 460000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GAG1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532571")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 470000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FIU1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532481")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 570000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='TRTR', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532611")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 580000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SNTG', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515401")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 580000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SNTG', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235271")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 620000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SNTG', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235261")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 650000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MTL1', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 29, 16, 1, 6))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515381")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 690000) [uncertainty=0.1]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='T0110', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532621")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 690000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='T0110', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 11))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133532631")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 840000) [uncertainty=3.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='EL6', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=9")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='SURVEY-INGV', creation_time=UTCDateTime(2016, 8, 24, 1, 53, 12))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=133515461")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 840000) [uncertainty=1.0]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='EL6', channel_code='EHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=17")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'automatic'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='hew1_mole#MOD_EQASSEMBLE', creation_time=UTCDateTime(2016, 8, 24, 1, 37, 4))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140940621")
# 	            time: UTCDateTime(2016, 8, 24, 1, 36, 43, 900000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='FEMA', channel_code='HNZ', location_code='')
# ...
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='STV', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886661")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 43, 590000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='IVPL', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886561")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 43, 650000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='JOPP', channel_code='HNN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886541")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 43, 750000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MPG', channel_code='SHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886611")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 45, 310000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MILZ', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910601")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 45, 470000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='TRAV', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910511")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 45, 970000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='PZZ', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910681")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 46, 20000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='BHB', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886501")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 46, 420000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MSRU', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910631")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 46, 920000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='RSP', channel_code='HNN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886571")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 47) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='GIB', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886641")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 47, 140000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='PLLN', channel_code='EHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886651")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 47, 160000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MSFR', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886621")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 47, 210000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MPNC', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910501")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 47, 330000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='CH', station_code='DAVOX', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886671")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 48, 70000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='MN', station_code='CEL', channel_code='HNZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910711")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 48, 100000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='CH', station_code='FUSIO', channel_code='HHZ', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'positive'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910481")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 48, 320000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='CH', station_code='MMK', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886511")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 48, 640000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='PLAC', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886581")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 50, 560000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='MTTG', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886521")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 51, 270000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='IV', station_code='SOI', channel_code='EHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'negative'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 2, 27))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910721")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 53, 120000) [uncertainty=0.3]
# 	     waveform_id: WaveformStreamID(network_code='GU', station_code='REMY', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910491")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 53, 460000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='MN', station_code='BNI', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910661")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 54, 840000) [uncertainty=1.0]
# 	     waveform_id: WaveformStreamID(network_code='CH', station_code='DIX', channel_code='HHN', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))
# Pick
# 	     resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910531")
# 	            time: UTCDateTime(2016, 8, 24, 1, 37, 55, 560000) [uncertainty=0.6]
# 	     waveform_id: WaveformStreamID(network_code='CH', station_code='BNALP', channel_code='HHE', location_code='')
# 	       method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodID=11")
# 	           onset: 'questionable'
# 	      phase_hint: 'P'
# 	        polarity: 'undecidable'
# 	 evaluation_mode: 'manual'
# 	   creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 8, 43, 13))

# %% [markdown]
# ```{div} full-width
#
# Also, checking the preferred `origin` of the event, we can see that now there is an additional field named `arrivals`
#
# ```

# %%
origin = event.preferred_origin()
print(origin)
# Out:
# Origin
# 	        resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?originId=27629391")
# 	               time: UTCDateTime(2016, 8, 24, 1, 36, 32) [uncertainty=0.03]
# 	          longitude: 13.2335 [uncertainty=0.0024]
# 	           latitude: 42.6983 [uncertainty=0.0009]
# 	              depth: 8100.0 [uncertainty=200.0]
# 	         depth_type: 'from location'
# 	          method_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1")
# 	     earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	            quality: OriginQuality(associated_phase_count=289, used_phase_count=289, associated_station_count=280, used_station_count=280, standard_error=0.11, azimuthal_gap=28.0, minimum_distance=0.10072, maximum_distance=5.38694)
# 	        origin_type: 'hypocenter'
# 	 origin_uncertainty: OriginUncertainty(horizontal_uncertainty=150.0, min_horizontal_uncertainty=132.0, max_horizontal_uncertainty=154.0, azimuth_max_horizontal_uncertainty=76.0, preferred_description='uncertainty ellipse', confidence_level=68.0)
# 	    evaluation_mode: 'manual'
# 	  evaluation_status: 'reviewed'
# 	      creation_info: CreationInfo(agency_id='INGV', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 31, 6, 40, 9), version='1000')
# 	               ---------
# 	           arrivals: 289 Elements

# %% [markdown]
# ```{div} full-width
#
# Giving a look to the list `origin.arrivals`, we can understand that each `arrival` contains information like the `pick_id` (which can be used for associated the specific `arrival` to one `pick` of the list of the `event.picks`), the epicentral `distance` (in degrees) from the estimated origin to the seismic station, the `time_residual` of the observed and modelled travel time ànd the `time_weight` (in percent, so we shall divide them by 100) that we already discussed in section ()
#
# ```

# %%
for arrival in origin.arrivals:
    print(arrival)
# Out:
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617441")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910531")
# 	          phase: 'P'
# 	        azimuth: 322.0
# 	       distance: 5.3869
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.05
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617431")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910661")
# 	          phase: 'P'
# 	        azimuth: 311.0
# 	       distance: 5.3591
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.71
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617421")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910491")
# 	          phase: 'P'
# 	        azimuth: 299.0
# 	       distance: 5.2745
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.5
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617411")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910721")
# 	          phase: 'P'
# 	        azimuth: 308.0
# 	       distance: 5.3618
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.04
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617401")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886521")
# 	          phase: 'P'
# 	        azimuth: 154.0
# 	       distance: 5.0965
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.77
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617391")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886581")
# 	          phase: 'P'
# 	        azimuth: 157.0
# 	       distance: 5.0542
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.64
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617381")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886511")
# 	          phase: 'P'
# 	        azimuth: 149.0
# 	       distance: 4.8941
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.94
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617351")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886671")
# 	          phase: 'P'
# 	        azimuth: 155.0
# 	       distance: 4.8743
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.64
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617361")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910711")
# 	          phase: 'P'
# 	        azimuth: 321.0
# 	       distance: 4.9679
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.38
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617371")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910481")
# 	          phase: 'P'
# 	        azimuth: 314.0
# 	       distance: 5.0389
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.38
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617301")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886571")
# 	          phase: 'P'
# 	        azimuth: 172.0
# 	       distance: 4.7439
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.37
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617311")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886641")
# 	          phase: 'P'
# 	        azimuth: 171.0
# 	       distance: 4.7538
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.38
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617331")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886621")
# 	          phase: 'P'
# 	        azimuth: 160.0
# 	       distance: 4.8267
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.44
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617321")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886651")
# 	          phase: 'P'
# 	        azimuth: 167.0
# 	       distance: 4.7745
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.11
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617341")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910501")
# 	          phase: 'P'
# 	        azimuth: 331.0
# 	       distance: 4.7232
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.98
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617291")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910631")
# 	          phase: 'P'
# 	        azimuth: 302.0
# 	       distance: 4.9436
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.47
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617271")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910681")
# 	          phase: 'P'
# 	        azimuth: 298.0
# 	       distance: 4.8078
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.5
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617281")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886501")
# 	          phase: 'P'
# 	        azimuth: 158.0
# 	       distance: 4.7574
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.61
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617261")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910511")
# 	          phase: 'P'
# 	        azimuth: 294.0
# 	       distance: 4.7808
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.83
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617251")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910601")
# 	          phase: 'P'
# 	        azimuth: 307.0
# 	       distance: 4.8384
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.46
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617241")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886611")
# 	          phase: 'P'
# 	        azimuth: 160.0
# 	       distance: 4.6774
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.6
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617221")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886561")
# 	          phase: 'P'
# 	        azimuth: 153.0
# 	       distance: 4.5569
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.61
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617201")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910691")
# 	          phase: 'P'
# 	        azimuth: 292.0
# 	       distance: 4.5542
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.54
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617231")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886541")
# 	          phase: 'P'
# 	        azimuth: 179.0
# 	       distance: 4.5344
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.01
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617181")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910671")
# 	          phase: 'P'
# 	        azimuth: 333.0
# 	       distance: 4.4516
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.42
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617191")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877031")
# 	          phase: 'P'
# 	        azimuth: 139.0
# 	       distance: 4.4301
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.78
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617211")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886661")
# 	          phase: 'P'
# 	        azimuth: 162.0
# 	       distance: 4.5182
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.08
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617171")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910471")
# 	          phase: 'P'
# 	        azimuth: 292.0
# 	       distance: 4.484
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.51
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617161")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886591")
# 	          phase: 'P'
# 	        azimuth: 162.0
# 	       distance: 4.4444
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.87
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617111")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910701")
# 	          phase: 'P'
# 	        azimuth: 330.0
# 	       distance: 4.3608
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.68
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617151")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905081")
# 	          phase: 'P'
# 	        azimuth: 335.0
# 	       distance: 4.3554
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.59
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617121")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876951")
# 	          phase: 'P'
# 	        azimuth: 223.0
# 	       distance: 4.4615
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.7
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617141")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140904981")
# 	          phase: 'P'
# 	        azimuth: 344.0
# 	       distance: 4.4202
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.67
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617131")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910651")
# 	          phase: 'P'
# 	        azimuth: 316.0
# 	       distance: 4.4975
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.42
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617101")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905041")
# 	          phase: 'P'
# 	        azimuth: 350.0
# 	       distance: 4.3248
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.66
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617081")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876941")
# 	          phase: 'P'
# 	        azimuth: 223.0
# 	       distance: 4.3212
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.58
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617061")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886551")
# 	          phase: 'P'
# 	        azimuth: 166.0
# 	       distance: 4.2547
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.44
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617091")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877061")
# 	          phase: 'P'
# 	        azimuth: 139.0
# 	       distance: 4.1944
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.86
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617071")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886531")
# 	          phase: 'P'
# 	        azimuth: 168.0
# 	       distance: 4.2484
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.57
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617041")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886631")
# 	          phase: 'P'
# 	        azimuth: 159.0
# 	       distance: 4.1809
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.45
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617021")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910591")
# 	          phase: 'P'
# 	        azimuth: 303.0
# 	       distance: 4.1261
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.77
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616991")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140886601")
# 	          phase: 'P'
# 	        azimuth: 181.0
# 	       distance: 3.9885
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.81
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617011")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910621")
# 	          phase: 'P'
# 	        azimuth: 291.0
# 	       distance: 4.1639
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.9
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617031")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877001")
# 	          phase: 'P'
# 	        azimuth: 142.0
# 	       distance: 4.1162
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.98
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516617001")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877051")
# 	          phase: 'P'
# 	        azimuth: 144.0
# 	       distance: 4.1333
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.06
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616971")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905111")
# 	          phase: 'P'
# 	        azimuth: 341.0
# 	       distance: 4.0317
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.69
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616981")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876981")
# 	          phase: 'P'
# 	        azimuth: 146.0
# 	       distance: 4.1108
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.71
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616951")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910571")
# 	          phase: 'P'
# 	        azimuth: 289.0
# 	       distance: 4.0676
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.54
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616961")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905021")
# 	          phase: 'P'
# 	        azimuth: 340.0
# 	       distance: 4.0389
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.97
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616931")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910611")
# 	          phase: 'P'
# 	        azimuth: 306.0
# 	       distance: 3.796
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.53
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616941")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910561")
# 	          phase: 'P'
# 	        azimuth: 292.0
# 	       distance: 4.0083
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.24
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616911")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140904971")
# 	          phase: 'P'
# 	        azimuth: 331.0
# 	       distance: 3.8761
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.24
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616891")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910641")
# 	          phase: 'P'
# 	        azimuth: 296.0
# 	       distance: 3.8968
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.52
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616921")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877021")
# 	          phase: 'P'
# 	        azimuth: 141.0
# 	       distance: 3.8302
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.94
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616901")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910581")
# 	          phase: 'P'
# 	        azimuth: 294.0
# 	       distance: 3.9255
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.28
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616861")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140904941")
# 	          phase: 'P'
# 	        azimuth: 359.0
# 	       distance: 3.8491
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.26
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616881")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902271")
# 	          phase: 'P'
# 	        azimuth: 357.0
# 	       distance: 3.8626
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.44
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616851")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877041")
# 	          phase: 'P'
# 	        azimuth: 146.0
# 	       distance: 3.7727
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.28
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616831")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910731")
# 	          phase: 'P'
# 	        azimuth: 300.0
# 	       distance: 3.859
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.11
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616821")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910541")
# 	          phase: 'P'
# 	        azimuth: 325.0
# 	       distance: 3.7897
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.64
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616811")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877071")
# 	          phase: 'P'
# 	        azimuth: 139.0
# 	       distance: 3.662
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.37
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616841")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905001")
# 	          phase: 'P'
# 	        azimuth: 335.0
# 	       distance: 3.7529
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.38
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616871")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902331")
# 	          phase: 'P'
# 	        azimuth: 3.0
# 	       distance: 3.8527
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.38
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616781")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876991")
# 	          phase: 'P'
# 	        azimuth: 137.0
# 	       distance: 3.5802
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.51
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616801")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902301")
# 	          phase: 'P'
# 	        azimuth: 356.0
# 	       distance: 3.7646
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.22
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616791")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140910521")
# 	          phase: 'P'
# 	        azimuth: 320.0
# 	       distance: 3.5982
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.35
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616741")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902291")
# 	          phase: 'P'
# 	        azimuth: 1.0
# 	       distance: 3.7079
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.18
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616751")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140904951")
# 	          phase: 'P'
# 	        azimuth: 358.0
# 	       distance: 3.7169
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.07
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616771")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902351")
# 	          phase: 'P'
# 	        azimuth: 3.0
# 	       distance: 3.7493
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.09
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616761")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905071")
# 	          phase: 'P'
# 	        azimuth: 334.0
# 	       distance: 3.6476
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.04
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616731")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902311")
# 	          phase: 'P'
# 	        azimuth: 351.0
# 	       distance: 3.6548
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.21
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616721")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905051")
# 	          phase: 'P'
# 	        azimuth: 330.0
# 	       distance: 3.5964
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.77
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616661")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140904961")
# 	          phase: 'P'
# 	        azimuth: 327.0
# 	       distance: 3.5056
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.93
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616671")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877011")
# 	          phase: 'P'
# 	        azimuth: 143.0
# 	       distance: 3.4867
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.39
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616691")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902341")
# 	          phase: 'P'
# 	        azimuth: 354.0
# 	       distance: 3.5793
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.17
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616681")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140905091")
# 	          phase: 'P'
# 	        azimuth: 336.0
# 	       distance: 3.5011
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.24
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616701")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876961")
# 	          phase: 'P'
# 	        azimuth: 53.0
# 	       distance: 3.5128
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.18
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616711")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902261")
# 	          phase: 'P'
# 	        azimuth: 301.0
# 	       distance: 3.5703
# 	  takeoff_angle: 38.0
# 	  time_residual: 0.49
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616621")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877171")
# 	          phase: 'P'
# 	        azimuth: 133.0
# 	       distance: 3.3311
# 	  takeoff_angle: 38.0
# 	  time_residual: 2.09
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616651")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140877181")
# 	          phase: 'P'
# 	        azimuth: 122.0
# 	       distance: 3.4354
# 	  takeoff_angle: 38.0
# 	  time_residual: 1.36
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616611")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140902321")
# 	          phase: 'P'
# 	        azimuth: 5.0
# 	       distance: 3.4849
# 	  takeoff_angle: 38.0
# 	  time_residual: -0.11
# 	    time_weight: 0.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516616631")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140236661")
# 	          phase: 'P'
# 	        azimuth: 258.0
# 	       distance: 3.3922
# ...
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614881")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235271")
# 	          phase: 'P'
# 	        azimuth: 339.0
# 	       distance: 0.5963
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.39
# 	    time_weight: 71.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614851")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876701")
# 	          phase: 'P'
# 	        azimuth: 77.0
# 	       distance: 0.5108
# 	  takeoff_angle: 50.0
# 	  time_residual: 0.68
# 	    time_weight: 81.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614871")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235241")
# 	          phase: 'P'
# 	        azimuth: 347.0
# 	       distance: 0.5531
# 	  takeoff_angle: 50.0
# 	  time_residual: 0.19
# 	    time_weight: 64.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614841")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235201")
# 	          phase: 'P'
# 	        azimuth: 336.0
# 	       distance: 0.5378
# 	  takeoff_angle: 50.0
# 	  time_residual: 0.12
# 	    time_weight: 67.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614831")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235171")
# 	          phase: 'P'
# 	        azimuth: 309.0
# 	       distance: 0.5441
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.07
# 	    time_weight: 89.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614811")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235111")
# 	          phase: 'P'
# 	        azimuth: 21.0
# 	       distance: 0.4712
# 	  takeoff_angle: 50.0
# 	  time_residual: 0.26
# 	    time_weight: 71.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614621")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140975921")
# 	          phase: 'S'
# 	        azimuth: 105.0
# 	       distance: 0.2824
# 	  takeoff_angle: 104.0
# 	  time_residual: -0.34
# 	    time_weight: 47.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614821")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235181")
# 	          phase: 'P'
# 	        azimuth: 356.0
# 	       distance: 0.5315
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.09
# 	    time_weight: 91.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614791")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235161")
# 	          phase: 'P'
# 	        azimuth: 149.0
# 	       distance: 0.5036
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.4
# 	    time_weight: 67.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614801")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235141")
# 	          phase: 'P'
# 	        azimuth: 352.0
# 	       distance: 0.4982
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.24
# 	    time_weight: 70.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614751")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235091")
# 	          phase: 'P'
# 	        azimuth: 54.0
# 	       distance: 0.4074
# 	  takeoff_angle: 50.0
# 	  time_residual: 0.28
# 	    time_weight: 95.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614781")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235121")
# 	          phase: 'P'
# 	        azimuth: 260.0
# 	       distance: 0.4838
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.12
# 	    time_weight: 97.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614761")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235101")
# 	          phase: 'P'
# 	        azimuth: 191.0
# 	       distance: 0.4389
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.07
# 	    time_weight: 99.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614731")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235071")
# 	          phase: 'P'
# 	        azimuth: 322.0
# 	       distance: 0.3894
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.33
# 	    time_weight: 94.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614601")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140940611")
# 	          phase: 'S'
# 	        azimuth: 184.0
# 	       distance: 0.1898
# 	  takeoff_angle: 111.0
# 	  time_residual: 0.28
# 	    time_weight: 48.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614671")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235021")
# 	          phase: 'P'
# 	        azimuth: 342.0
# 	       distance: 0.3543
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.29
# 	    time_weight: 95.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614721")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140876761")
# 	          phase: 'P'
# 	        azimuth: 12.0
# 	       distance: 0.3714
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.2
# 	    time_weight: 97.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614711")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235041")
# 	          phase: 'P'
# 	        azimuth: 251.0
# 	       distance: 0.3642
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.25
# 	    time_weight: 96.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614651")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235011")
# 	          phase: 'P'
# 	        azimuth: 134.0
# 	       distance: 0.3498
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.48
# 	    time_weight: 91.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614691")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140235051")
# 	          phase: 'P'
# 	        azimuth: 160.0
# 	       distance: 0.3669
# 	  takeoff_angle: 50.0
# 	  time_residual: -0.47
# 	    time_weight: 91.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614631")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140924221")
# 	          phase: 'P'
# 	        azimuth: 333.0
# 	       distance: 0.2959
# 	  takeoff_angle: 104.0
# 	  time_residual: -0.04
# 	    time_weight: 100.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614581")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140975911")
# 	          phase: 'S'
# 	        azimuth: 236.0
# 	       distance: 0.1709
# 	  takeoff_angle: 113.0
# 	  time_residual: -0.44
# 	    time_weight: 46.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614611")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234971")
# 	          phase: 'P'
# 	        azimuth: 105.0
# 	       distance: 0.2824
# 	  takeoff_angle: 104.0
# 	  time_residual: -0.68
# 	    time_weight: 85.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614571")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234931")
# 	          phase: 'P'
# 	        azimuth: 236.0
# 	       distance: 0.1709
# 	  takeoff_angle: 113.0
# 	  time_residual: 0.41
# 	    time_weight: 93.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614561")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140236691")
# 	          phase: 'P'
# 	        azimuth: 327.0
# 	       distance: 0.161
# 	  takeoff_angle: 114.0
# 	  time_residual: 0.07
# 	    time_weight: 99.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614591")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140234951")
# 	          phase: 'P'
# 	        azimuth: 184.0
# 	       distance: 0.1898
# 	  takeoff_angle: 111.0
# 	  time_residual: 0.32
# 	    time_weight: 94.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))
# Arrival
# 	    resource_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?arrivalId=516614551")
# 	        pick_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?pickId=140940591")
# 	          phase: 'P'
# 	        azimuth: 132.0
# 	       distance: 0.1007
# 	  takeoff_angle: 126.0
# 	  time_residual: 0.14
# 	    time_weight: 98.0
# 	 earth_model_id: ResourceIdentifier(id="smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1")
# 	  creation_info: CreationInfo(agency_id='INGV ', author='BULLETIN-INGV', creation_time=UTCDateTime(2016, 8, 30, 10, 32, 53))

# %% [markdown]
# ```{div} full-width
#
# Checking the number of picks and of arrivals, we can see that only a fraction of the former (about one third) have been actually used for locating the earthquake
#
# ```

# %%
print("number of picks:    ",len(event.picks))
print("number of arrivals: ",len(origin.arrivals))
# Out:
# number of picks:     699
# number of arrivals:  289

# %% [markdown]
# ```{div} full-width
#
# This is because the list `event.picks` contains all the picking made by all the authors that studied this earthquakes, while the list `origin.arrivals` contains only the arrivals used for estimating the preferred `origin`.  Also, as we can see, each `arrival` have a field `pick_id` that can be used to associate it to a specific `pick`. We will exploit this fact in the next section.
#
#
# In addition to it, plotting the time weights of the arrivals against the epicentral distance, we can see that the assigned weight decrease with the epicentral distance and that only arrivals within the first 100 km have been actually used (the weights at greater distances being zeros). Also, we can see that all the arrivals for the S waves are weighted by about one half with respect to the arrivals for P waves at similar distances. This is beacuse the picking of the S waves is much more questionable than that of the P waves.
#
# ```

# %%
earth_radius = 6371.009
deg2km = np.pi/180 * earth_radius

fig,ax = plt.subplots(tight_layout=True)
for phase in ["P","S"]:
    distances = [ arrival.distance * deg2km for arrival in origin.arrivals if arrival.phase == phase]
    weights   = [ arrival.time_weight / 100 for arrival in origin.arrivals if arrival.phase == phase]
    ax.scatter(distances,weights,label=phase,marker=".")
ax.set_xlabel("Distance [km]")
ax.set_ylabel("Weight")
ax.legend();

# %% [markdown]
# ### Picking selection

# %% [markdown]
# ```{div} full-width
#
# Let us thus select only those picks that have been used in the earthquake localization of the preferred origin
#
# ```

# %%
pick_ids = [arrival.pick_id for arrival in origin.arrivals]
origin_picks = [pick for pick in event.picks if pick.resource_id in pick_ids]

print("Number of picks:                            ",len(event.picks))
print("Number of arrivals:                         ",len(origin.arrivals))
print("Number of picks associated to the arrivals: ",len(origin_picks))
# Out:
# Number of picks:                             699
# Number of arrivals:                          289
# Number of picks associated to the arrivals:  289

# %% [markdown]
# ```{div} full-width
#
# As we can see, we succeed in selecting only the picks associated to the arrivals.
#
# Let us now obtain and organize all the informations that we need for defining the inverse problem of the earthquake location with similar settings to those used by the Istituto Nazionale di Geofisica e vulcanologia. First we make a lists of picks and arrivals where, for each arrival with a non-zero weight we associated the corresponding pick.
#
# ```

# %%
picks_arrivals = []
for arrival in origin.arrivals:
    if arrival.time_weight == 0.0: continue
    for pick in origin_picks:
        if pick.resource_id == arrival.pick_id:
            picks_arrivals.append([pick,arrival])
            break
print("Number of selected picks and arrivals:",len(picks_arrivals))
# Out:
# Number of selected picks and arrivals: 56

# %% [markdown]
# ```{div} full-width
#
# From this list (which contains only 56 couples of picks and arrivals, because all the others have zero weight) we can obtain the piciking time and its uncertainity (or standard deviations) from the pick and the assigned weight from the arrival. In addition to it, we shall obtain the spatial coordinate of the seismic station (longitude, latitude and elevation) to which each picking refers. Unfortunatly, the geopgarphical coordinate are not ready available niether from the pick or the arrival and, so, we shall make use of the waveform identifiers contained in the picks along with an inventory of the seismic networks from which we can obtain the geographical coordinates. In this perspective, we download all the seismic stations within about 100 km (1 degrees) from the epicenter that have operate one hour before and one hour after the origin time.
#
# ```

# %%
circle = dict(maxradius=1,longitude=origin.longitude,latitude=origin.latitude)

# %% [markdown]
# ```{div} full-width
#
# and plot it along with the catalog containing the only Accumoli earthquake
#
# ```

# %%
fig = lab.setup_map(circle,color="red")
fig = inventory.plot(fig=fig,label=False,size=30,show=False,color="orange")

# %% [markdown]
# ```{div} full-width
#
# Then, we extent the list of picks and arrivals including also the channels from the inventory corresponding to those to which the picks refer
#
# ```

# %%
picks_arrivals_channels = []
for pick, arrival in picks_arrivals:
    waveform_id = pick.waveform_id.id
    codes = waveform_id.split(".")
    inv = inventory.select(*codes)
    try:
        channel = inv[0][0][0]
        picks_arrivals_channels.append([pick,arrival,channel])
    except:
        print("Warning! There is no the channel "+waveform_id+" to which the pick refer")

# %% [markdown]
# ```{div} full-width
#
# The `try` and `except` syntax has been used to prevent from an error in the case in which the channel is not found in the inventory. Fortunately, in the present case, all the channels that we need have been found.
#
# In order to have an idea of how many seismic stations have been considered by the INGV for locating the earthquake, we now make the same plot as before but indicating with the green mark (and the station code) those seismic stations that have been actually used.
#
# ```

# %%
import cartopy

fig = lab.setup_map(circle,color="red")
fig = inventory.plot(fig=fig,label=False,size=30,show=False,color="orange")

ax = fig.axes[0]
for pick, arrival, channel in picks_arrivals_channels:
    label = pick.waveform_id.id.split(".")[1]
    ax.scatter(channel.longitude,channel.latitude,marker="v",color="green",transform=cartopy.crs.PlateCarree(),zorder=30)
    ax.annotate(label,xy=(channel.longitude+0.02,channel.latitude),transform=cartopy.crs.PlateCarree(),zorder=30)

# %% [markdown]
# ```{div} full-width
#
# Among all these channels, it will be useful to identify the closest one, i.e., the one for which has been made the early picking
#
# ```

# %%
times = [ pick.time for pick, _, _ in picks_arrivals_channels ]

i0 = np.argmin(times)
ref_pick, ref_arrival, ref_channel = picks_arrivals_channels[i0]

ref_time = ref_pick.time
ref_longitude, ref_latitude = ref_channel.longitude, ref_channel.latitude
ref_code = ref_pick.waveform_id.id

print("ref_code: ",ref_code)
print("ref_time:",ref_time)
print(ref_longitude,ref_latitude)
# Out:
# ref_code:  IV.SMA1..EHZ
# ref_time: 2016-08-24T01:36:34.910000Z
# 13.3353 42.6305

# %%
from myst_nb import glue
glue("ref_code", ref_code)
# Out:
# 'IV.SMA1..EHZ'

# %% [markdown]
# ```{div} full-width
# As far as we know, without performing the full inversion of the observations, the picking time, longitude and latitude of the channels {glue:}`ref_code` are the closest one to the actual origin and, so, we can use it as first guess for minimizing the WRSS.
# ```

# %% [markdown]
# ### Data organization and the azimuthal equidistant projection

# %% [markdown]
# ```{div} full-width
#
# We are now in the position of obtaining all the informations that we need for defining the inverse problem: the picking time, the longitude, latitude and elevation of the seismic station, the picking uncertainity, the weight assigned to the arrival and the phase.
#
# Rather than obtaining the picking time in UTCDateTime, we will consider a reference time and compute the differences with respect to it in order to obtain the picking time in seconds
#
# ```

# %%
N = len(picks_arrivals_channels)
data = np.empty((N,6))
for i,(pick,arrival,channel) in enumerate(picks_arrivals_channels):
        
        T = pick.time - ref_time
        E = pick.time_errors["uncertainty"]
        scale = arrival.time_weight/100
        E /= np.sqrt(scale)

        lon,lat = channel.longitude, channel.latitude
        Z = channel.elevation
        
        phase = int(pick.phase_hint == "S")

        data[i] = [T,lon,lat,Z,E,phase]
        
print("{0:>9}  {1:>9}  {2:>9}  {3:>9}  {4:>9}  {5:>9}".format("t [s]","lat [°]","lon [°]","z [m]","std [s]","phase"))
for datum in data:
    print("{0:>9.4f}  {1:>9.4f}  {2:>9.4f}  {3:>9.4f}  {4:>9.4f}  {5:>9d}".format(*datum[:-1],int(datum[-1])))
# Out:
#     t [s]    lat [°]    lon [°]      z [m]    std [s]      phase
#   13.4800    12.5715    43.3666   960.0000     0.4082          0
#   13.1900    12.3536    43.1979   929.0000     0.3536          0
#   13.9400    12.1121    42.9126   547.0000     2.1213          0
#   13.7900    13.1172    42.2680  1070.0000     0.9045          1
#   13.2300    12.9415    43.4981   461.0000     0.4082          0
#   13.5400    12.4073    43.3152   584.0000     0.7071          0
#   12.5000    12.9973    43.4418   800.0000     0.8018          0
#   12.4300    12.9818    41.9490   773.0000     0.8321          0
#   12.9500    12.7822    43.4363   750.0000     1.1339          0
#   12.1300    13.6095    43.3778    21.0000     0.6882          0
#   12.1900    12.9046    43.0049   840.0000     0.8847          1
#   12.2300    12.5246    43.2630   845.0000     0.7746          0
#   12.9200    13.9046    42.0115   924.0000     2.1213          0
#   12.1600    12.7422    42.0228   388.0000     0.2236          0
#   11.9400    13.6701    43.3053   163.0000     1.6036          0
#   11.3100    13.4006    42.0219   957.0000     0.1601          0
#   11.0900    13.4050    42.3540   710.0000     0.8485          1
#   10.4000    13.1954    43.3756   626.0000     0.1429          0
#   10.5900    13.0873    43.0365   550.0000     0.8571          1
#   10.6500    13.5728    42.4532   960.0000     0.8485          1
#   10.8800    12.5099    42.2370   410.0000     0.5571          0
#   10.7800    12.7612    43.2948   559.0000     0.1508          0
#    9.9100    12.6399    43.1851   557.0000     0.4629          0
#    9.8300    13.1017    43.3293   978.0000     0.4376          0
#    9.8500    13.3128    43.3112   330.0000     0.4286          0
#    9.3700    13.7763    42.2294   915.0000     0.4160          0
#    8.7400    13.0096    43.2567   353.0000     0.3906          0
#    8.5100    13.8406    42.3946  1185.0000     0.1091          0
#    8.9900    13.0498    42.9621  1370.0000     0.8571          1
#    8.7100    12.9406    43.2550   650.0000     0.1187          0
#    8.3200    13.9138    42.8081   160.0000     0.1111          0
#    8.5500    13.0674    43.2381   484.0000     0.3750          0
#    8.2100    12.9316    43.1886   479.0000     0.3665          0
#    8.1300    12.6587    43.0426   734.0000     0.1060          0
#    7.2300    13.4693    43.1374   325.0000     0.3560          0
#    7.9900    13.6039    42.6228   673.0000     0.8752          1
#    7.9100    13.1770    43.2288   240.0000     0.1048          0
#    7.1100    13.5838    42.2657   761.0000     0.3665          0
#    7.1900    13.1427    43.1927   940.0000     0.3586          0
#    6.1500    13.6857    42.9350   320.0000     0.1026          0
#    7.0500    12.5868    42.6085   458.0000     0.1015          0
#    6.3300    13.1172    42.2680  1070.0000     0.1005          0
#    5.2400    12.9046    43.0049   840.0000     0.1031          0
#    5.1900    13.2145    42.5090  1097.0000     0.8660          1
#    4.6700    13.0873    43.0365   550.0000     0.1026          0
#    5.0600    13.3352    43.0627   574.0000     0.1015          0
#    4.8700    12.7657    42.5792   253.0000     0.1021          0
#    4.4000    13.5728    42.4532   960.0000     0.1048          0
#    4.7000    13.4050    42.3540   710.0000     0.1048          0
#    3.8300    13.0498    42.9621  1370.0000     0.1000          0
#    3.8100    13.0403    42.6029  1155.0000     0.8847          1
#    2.9000    13.6039    42.6228   673.0000     0.1085          0
#    1.6300    13.0403    42.6029  1155.0000     0.1037          0
#    1.0900    13.1143    42.8336   927.0000     0.1005          0
#    1.9300    13.2145    42.5090  1097.0000     0.1031          0
#    0.0000    13.3353    42.6305  1150.0000     0.1010          0

# %% [markdown]
# ```{div} full-width
#
# In order to simplify the modelling of the travel times of the seismic wave to the seismic station and because we are considering a very small area of the Earth surface, we will consider a Cartesian reference system and use the elevation as vertical coordinate $x_3$ and the $x_1$ and $x_2$ coordinates of the azimuthal equidistant projection for the horizontal coordinates. The azimuthal equidistant projection is implemented in the module `cartopy`. As already discussed in {numref}`Lecture %s <chap-L1>` {ref}`chap-geographic-maps`, here the syntax required for the coordinate change from the geographical reference system to the Cartesian one
#
# ```

# %%
projection = cartopy.crs.AzimuthalEquidistant(central_longitude=ref_longitude, central_latitude=ref_latitude)
geodetic   = cartopy.crs.Geodetic()

llz = data[:,1:4].T  #longitude, latitude, elevation
xyz = projection.transform_points(geodetic,*llz)
xyz /= 1e3

data[:,1:4] = xyz #Cartesian coordinates x, y, z

print("{0:>9}  {1:>9}  {2:>9}  {3:>9}  {4:>9}  {5:>9}".format("t [s]","x [km]","y [km]","z [km]","std [s]","phase"))
for datum in data:
    print("{0:>9.4f}  {1:>9.4f}  {2:>9.4f}  {3:>9.4f}  {4:>9.4f}  {5:>9d}".format(*datum[:-1],int(datum[-1])))
# Out:
#     t [s]     x [km]     y [km]     z [km]    std [s]      phase
#   13.4800   -61.9103    82.0561     0.9600     0.4082          0
#   13.1900   -79.7909    63.4977     0.9290     0.3536          0
#   13.9400   -99.8758    32.0647     0.5470     2.1213          0
#   13.7900   -17.9955   -40.2419     1.0700     0.9045          1
#   13.2300   -31.8489    96.4563     0.4610     0.4082          0
#   13.5400   -75.2856    76.4751     0.5840     0.7071          0
#   12.5000   -27.3634    90.1884     0.8000     0.8018          0
#   12.4300   -29.3150   -75.6360     0.7730     0.8321          0
#   12.9500   -44.7770    89.6639     0.7500     1.1339          0
#   12.1300    22.2216    83.0592     0.0210     0.6882          0
#   12.1900   -35.1170    41.6814     0.8400     0.8847          1
#   12.2300   -65.8229    70.5822     0.8450     0.7746          0
#   12.9200    47.1590   -68.5957     0.9240     2.1213          0
#   12.1600   -49.1201   -67.3316     0.3880     0.2236          0
#   11.9400    27.1642    75.0186     0.1630     1.6036          0
#   11.3100     5.4059   -67.5976     0.9570     0.1601          0
#   11.0900     5.7426   -30.7120     0.7100     0.8485          1
#   10.4000   -11.3382    82.7813     0.6260     0.1429          0
#   10.5900   -20.2103    45.1320     0.5500     0.8571          1
#   10.6500    19.5395   -19.6714     0.9600     0.8485          1
#   10.8800   -68.1277   -43.3836     0.4100     0.5571          0
#   10.7800   -46.5913    73.9605     0.5590     0.1508          0
#    9.9100   -56.5300    61.8486     0.5570     0.4629          0
#    9.8300   -18.9490    77.6613     0.9780     0.4376          0
#    9.8500    -1.8215    75.6205     0.3300     0.4286          0
#    9.3700    36.4086   -44.4557     0.9150     0.4160          0
#    8.7400   -26.4474    69.6203     0.3530     0.3906          0
#    8.5100    41.6039   -26.0860     1.1850     0.1091          0
#    8.9900   -23.2976    36.8764     1.3700     0.8571          1
#    8.7100   -32.0538    69.4518     0.6500     0.1187          0
#    8.3200    47.3177    19.8911     0.1600     0.1111          0
#    8.5500   -21.7579    67.5296     0.4840     0.3750          0
#    8.2100   -32.8173    62.0741     0.4790     0.3665          0
#    8.1300   -55.1324    46.0010     0.7340     0.1060          0
#    7.2300    10.8983    56.3180     0.3250     0.3560          0
#    7.9900    22.0378    -0.8215     0.6730     0.8752          1
#    7.9100   -12.8637    66.4762     0.2400     0.1048          0
#    7.1100    20.5018   -40.4893     0.7610     0.3665          0
#    7.1900   -15.6559    62.4733     0.9400     0.3586          0
#    6.1500    28.6021    33.8858     0.3200     0.1026          0
#    7.0500   -61.4220    -2.1737     0.4580     0.1015          0
#    6.3300   -17.9955   -40.2419     1.0700     0.1005          0
#    5.2400   -35.1170    41.6814     0.8400     0.1031          0
#    5.1900    -9.9266   -13.4919     1.0970     0.8660          1
#    4.6700   -20.2103    45.1320     0.5500     0.1026          0
#    5.0600    -0.0081    48.0130     0.5740     0.1015          0
#    4.8700   -46.7636    -5.5446     0.2530     0.1021          0
#    4.4000    19.5395   -19.6714     0.9600     0.1048          0
#    4.7000     5.7426   -30.7120     0.7100     0.1048          0
#    3.8300   -23.2976    36.8764     1.3700     0.1000          0
#    3.8100   -24.2072    -3.0282     1.1550     0.8847          1
#    2.9000    22.0378    -0.8215     0.6730     0.1085          0
#    1.6300   -24.2072    -3.0282     1.1550     0.1037          0
#    1.0900   -18.0716    22.5800     0.9270     0.1005          0
#    1.9300    -9.9266   -13.4919     1.0970     0.1031          0
#    0.0000     0.0000     0.0000     1.1500     0.1010          0

# %%
ingv = np.array([origin.time-ref_time,origin.longitude,origin.latitude,-origin.depth]) # [s,deg,deg,m]
llz = ingv[1:]  #longitude, latitude, elevation
xyz = projection.transform_points(geodetic,*llz)
xyz /= 1e3
ingv[1:] = xyz #Cartesian coordinates x, y, z


deg2km = np.pi/180 * earth_radius

ingv_std = np.empty(4)
ingv_std[0] = origin.time_errors["uncertainty"]
rlat = origin.latitude * np.pi/180
ingv_std[1] = origin.longitude_errors["uncertainty"] * deg2km * np.cos(rlat)
ingv_std[2] = origin.latitude_errors["uncertainty"]  * deg2km
ingv_std[3] = origin.depth_errors["uncertainty"] / 1e3

keys = ["T0 [s]","X0 [km]","Y0 [km]","Z0 [km]"]

print("\n{0:>8} {1:>8} {2:>8} ".format("","val","std"))
for key,val,std in zip(keys,ingv,ingv_std):
    print("{0:<8} {1:>8.4f} {2:>8.4f}".format(key,val,std))
# Out:
#               val      std
# T0 [s]    -2.9100   0.0300
# X0 [km]   -8.3414   0.1961
# Y0 [km]    7.5367   0.1001
# Z0 [km]   -8.1000   0.2000

# %% [markdown]
# ```{div} full-width
#
# In the list of arrivals it is also contained the time residual of each arrival, that is the difference between the picking time and the one modelled with the velocity model of the INGV. We use it to obtain the modelled times by INGV and we plot the data with respect to the origin and compare them with respect to the modelled ones
#
# ```

# %%
residues = np.array([arrival.time_residual for _, arrival, _ in picks_arrivals_channels])
modelled_times = data[0]- residues 
fig = lab.plot_data(data,origin=ingv,modelled_times=modelled_times)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 residues = np.array([arrival.time_residual for _, arrival, _ in picks_arrivals_channels])
# ----> 2 modelled_times = data[0]- residues
#       3 fig = lab.plot_data(data,origin=ingv,modelled_times=modelled_times)
#
# ValueError: operands could not be broadcast together with shapes (6,) (56,)

# %% [markdown]
# ```{div} full-width
#
# Let us now make the same figure plotting also two straight lines according to a simple velocity model with $v_p = 5$ km/s and $v_s = 3$ km/s
#
# ```

# %%
fig = lab.plot_data(data,origin=ingv,modelled_times=modelled_times)
T0,T1 = ingv[0],15
fig.axes[0].plot([T0,T1],[0,5*(T1-T0)],color="gold");
fig.axes[0].plot([T0,T1],[0,3*(T1-T0)],color="gold");

# %% [markdown]
# ## Homogeneous half-space velocity model
#
# ```{div} full-width
#
# In the simple case of an homogeneous half-space velocity model, we only need to specify the P and S wave seismic velocity
#
# ```

# %%
velocity_model = np.array([6,3])
print("velocity model:",velocity_model)

# %% [markdown]
# ```{div} full-width
#
# Let us define a function which compute the travel times for a set of hypocentral distances `Ds`, taking info account for the seismic phases `Ps` and the specified velocity model. This function correspons to the thoeoretical relationship between the model parameters and the observations, eq. {eq}`E:8`.
#
# ```

# %%
def eva_travel_times(Ds,Ps,velocity_model):
    
    VP,VS = velocity_model
        
    DTs_mod = np.empty(len(Ds))
    for i,(D,P) in enumerate(zip(Ds,Ps)):
        if P == 1:
            DTs_mod[i] = D/VS
        else:
            DTs_mod[i] = D/VP

    return DTs_mod

# %% [markdown]
# ```{div} full-width
#
# Then, we use it for defining another function which compute the weighte residual square sum (WRSS)), eq. {eq}`E:19`, for the model parameters $m$ collecting the origin time `TE` and cartesian coordinates `XE`, `YE` and `ZE` once given the `data` and the `velocity_model`
#
# ```

# %%
def eva_wrss(m,data,velocity_model):
    
    TE,XE,YE,ZE = m
    Ts,Xs,Ys,Zs,Es,Ps = data
    Ds = np.sqrt( (Xs-XE)**2 + (Ys-YE)**2 + (Zs-ZE)**2 )

    Ts_mod = eva_travel_times(Ds,Ps,velocity_model) + TE

    WRSS = (((Ts-Ts_mod)/Es)**2).sum()
        
    return WRSS

# %% [markdown]
# ```{div} full-width
#
# Here the so calculated WRSS for the origin `ingv` by the INGV according to the homogeneous half-space velocity model
#
# ```

# %%
wrss = eva_wrss(ingv,data,velocity_model)
print("wrss for the ingv:",wrss)

# %% [markdown]
# ```{div} full-width
#
# Making use of the submodule `optimize` from `scipy`, we can define the model space using the class `optimize.Bounds` and minimize the WRSS as function of the model parameters using the function `optimize.minimize`. By default, in presence of `bounds`, the minimization is made according to the L-BFGS-B method described in [Byrd et al. (1995)](https://epubs.siam.org/doi/10.1137/0916069) and [Zhu et al. (1997)](https://dl.acm.org/doi/10.1145/279232.279236) (click {download}`here<../_static/Byrd_etal_1995.pdf>` and {download}`here<../_static/Zhu_Byrd_1997.pdf>` for downloading the pdfs) .
# ```

# %%
from scipy import optimize

ub = [np.inf,np.inf,np.inf,0]
bounds = optimize.Bounds(ub=ub)  # definition of the upper bounds for the model parameters (i.e., the vertical coordinate ZE must be non-positive

fun = lambda m: eva_wrss(m,data,velocity_model)   # function to be minimized 

guess = [0,0,0,-10]   # starting point for the minimization
sol = optimize.minimize(fun, guess, bounds=bounds)     # minimizationb
print("Minimization solution:\n\n",sol)

# %% [markdown]
# ```{div} full-width
#
# We note that we have made use of the `lambda` syntax for defining the function `fun` of the only model parameters starting from the python function `eva_wrss`. Also, the function `optimize.minimize` return the object  `sol` which summarize the main information about the mninimization, including where the function takes its minimum, at `sol.x`, and the minimum value `sol.fun`.
#
# In order to verify that we found a minimum, let us plot the WRSS by varying one model parameter at the time and fixing the other to their most likelihood values
#
# ```

# %%
def plot_wrss(mb, exts, fun):

    fig,axes = plt.subplots(2,2,tight_layout=True,figsize=(8,8))
    axes = axes.flatten()
    for k,(key,ext) in enumerate(exts.items()):
        ax = axes[k]
        m = mb.copy()
        xs = np.linspace(*ext,1000) + mb[k]
        fs = np.empty(len(xs))
        for i,x in enumerate(xs):
            m[k] = x
            WRSS = fun(m)
            fs[i] = WRSS
        ax.plot(xs,fs)
        ax.axvline(mb[k],linewidth=0.5)
        ax.axhline(fs.min(),linewidth=0.5)
        ax.set_xlabel(key)
        ax.set_ylabel("WRSS")
        
    wrss = fun(mb)
    text = "WRSS: {0:>10.3f}    Model parameters: "+" ".join([ "{"+str(k)+":>7.3f}" for k in range(1,5) ])
    fig.suptitle(text.format(wrss,*mb))
    
    return fig

# %%
exts = { "TE [s]":[-0.2,0.2], "XE [km]": [-1,1], "YE [km]": [-1,1], "ZE [km]":[-1,1] }
fig = plot_wrss(sol.x, exts, fun)

# %% [markdown]
# ## Two layered half-space velocity model
#
# ```{div} full-width
#
# Let us imporve the velocity model by considering a two-layered Earth model consisting of the upper and lower crusts separated by the Conrad discontinuity at $11$ km depth.
#
# In doing this, let us consider a Cartesian reference system and denote with $\ell$ and $z$ the horizontal and vertical cordinates of the seismic station and set the hypocenter at $(0,z_e)$, with $z_e\leq 0$ and $z\geq 0$, as depicted in {numref}`Figure {number} <fig-velocity-model>`.
#
# ```
#
# ````{div} full-width
# ```{figure} ../images/Velocity_model.png
# ---
# align: center
# name: fig-velocity-model
# ---
# Cartoon depicting the Cartesian reference system and the ray path from the hypocenter at $(0,z_e)$ to the seismic station at $(\ell,z)$. The dashed line indicates the Conrad discontinuity at $z=H=-11$ km. We assume that the vertical coordinate of the seismic station is non-negative, $z\geq 0$, and denote with $\ell_c$ the horizontal component of the ray path within the lower crust.
# ```
# ````
#
# <font size="4"> Hypocenter in the upper crust </font>
#
# ```{div} full-width
#
# When the hypocenter is in the upper crust ($z_e \geq -H$), we have to compare the direct (red line) and headwave (green line) travel times $t_d$ and $t_h$ and select the smaller one
#
# $$
# \begin{align}
# & t = \min(t_d,t_h)
# \end{align}
# $$ (E:23)
#
# with
#
# $$
# \begin{align}
# & t_d = \frac{\sqrt{(z-z_e)^2 + \ell^2}}{c_0}
# \qquad\mathrm{and}\qquad
# t_h = \frac{\ell_c}{c_1} + \frac{ \sqrt{\Delta z^2 + \Delta \ell^2}}{c_1}
# \end{align}
# $$ (E:24)
#
# Here, $c_0$ and $c_1$ are the seismic wave velocities of the upper and lower crusts, while $\Delta \ell$ and $\Delta z$ are the horizontal and vertical components of the ray path of the headwave in the upper crust
#
# $$
# \begin{align}
# & \Delta l = \ell-\ell_c \geq 0 \qquad\mathrm{and}\qquad
# \Delta z = (z_e-H) + (z-H)  = z_e + z - 2\,H
# \end{align}
# $$ (E:25)
#
# In order to determine $\ell_c$, we note that the incident (or reflection) angle $\theta$ is given by
#
# $$
# \begin{align}
# & \tan\theta = \frac{\Delta \ell}{\Delta z}
# \end{align}
# $$ (E:26)
#
# and that the refraction angle (in the lower crust) must be $\pi/2$. In this respect, from the Snell's law, the indident angle must be
#
# $$
# \begin{align}
# &  \sin\theta = \frac{c_0}{c_1}  \qquad\Rightarrow\qquad \tan\theta = \frac{\sin\theta}{\cos\theta} = \frac{c_0}{\sqrt{c_1^2-c_0^2}}
# \end{align}
# $$ (E:27)
#
# We thus obtain
#
# $$
# \begin{align}
# & \Delta \ell = \tan\theta\,\Delta z\qquad\Rightarrow\qquad
# \ell_c = \ell - \Delta\ell = \ell - \tan\theta\,\Delta z
# \end{align}
# $$ (E:28)
#
# and we can rewrite the headwave travel time as follows
#
# $$
# \begin{align}
# & t_h = \frac{\ell_c}{v_1} + \Delta \ell\,\sqrt{\frac{c_1^2}{c_0^2}-1}
# \end{align}
# $$ (E:29)
#
# We note that the headwave is possible only when $\Delta \ell \geq 0$ or, equivalently, $\ell\geq \ell_c$.
#
# ```

# %% [markdown]
# <font size="4"> Hypocenter in the lower crust </font>
#
# ```{div} full-width
#
#
# When the hypocenter depth is the lower crust ($z_e<-H$), the travel time $t$ depend on the horizontal coordinate $x$ where the ray path encounter the Conrad discontinuity
#
# $$
# \begin{align}
# & t_d(\ell_c) = \frac{ \sqrt{\big(H-z_e\big)^2+\ell_c^2}}{v_1} + \frac{ \sqrt{(z-H)^2+\big(\ell-\ell_c\big)^2} }{v_0}
# \end{align}
# $$ (E:30)
#
#
#
# In order to determine $\ell_c$ we have to minimize eq. {eq}`E:30` within the interval  $[0,L]$
#
# $$
# \begin{align}
# & \frac{d t_d(\ell_c)}{d\ell_c} = \frac{\ell_c}{v_1\,\sqrt{(H-z_e)^2+\ell_c^2}} - \frac{\ell-\ell_c}{v_0\,\sqrt{(z-H)^2+(\ell-\ell_c)^2}} = 0
# \end{align}
# $$ (E:31)
#
# By equating the square of the two terms in the right-hand side and multuplying by the minimum common denominator, eq. {eq}`E:31` becomes
#
# $$
# \begin{align}
# & \ell_c^2\,(\ell-\ell_c)^2\,(v_1^2-v_0^2) - \ell_c^2\,v_0^2\,(z-H)^2 + (\ell-\ell_c)^2\,v_1^2\,(H-z_e)^2 = 0
# \end{align}
# $$ (E:32)
#
# Then, by introducing the following normalization
#
# $$
# \begin{align}
# & \ell_c = L\,\hat{\ell_c}
# \end{align}
# $$ (E:33)
#
# and defining
#
# $$
# \begin{align}
# & A_0 = \frac{v_0^2}{v_1^2-v_0^2}\,\frac{(z-H)^2}{\ell^2} = \frac{S\,B_0}{1-S} & \quad  A_1 = \frac{v_1^2}{v_1^2-v_0^2}\,\frac{(H-z_e)^2}{\ell^2} = \frac{B_1}{1-S}
# \end{align}
# $$  (E:34)
#
# with
#
# $$
# \begin{align}
# & S = \frac{v_0^2}{v_1^2} & \quad B_0 = \frac{(z-H)^2}{\ell^2}  \qquad B_1 = \frac{(H-z_e)^2}{\ell^2}
# \end{align}
# $$  (E:35)
#
# we obtain that $\hat{\ell}_c\in[0,1]$ must be a root of the following 4-order polynomial
#
# $$
# \begin{align}
# & \hat{\ell}^4\,-2\,\hat{\ell}^3  + \hat{\ell}^2\,(1 + A_1-A_0) - 2\,\hat{\ell}\,A_1 + A_1 = 0
# \end{align}
# $$  (E:36)
#
# By definition, there is only one real root of the above polynomial in the normalized interval $[0,1]$.
#
# ```

# %% [markdown]
# ### Optimization
#
# ```{div} full-width
#
# Here, we define the two layered velocity model
#
# ```

# %%
velocity_model = [5.00, 6.50, 2.89, 3.75, -11.1 ]

# %% [markdown]
# ```{div} full-width
# and we implement the python function computing the modelled travel time of the two-layered Earth model
# ```

# %%
#################################################################
def eva_travel_time(L, Z, ZE, V0, V1, H):
    
    sin0 = V0/V1
    S = sin0**2
    
    if ZE >= H:
        
        D = np.sqrt(L**2+(Z-ZE)**2)
        T = D/V0
        
        if sin0 < 1:
        
            cos0 = np.sqrt(1-S)

            DZ  = Z + ZE - 2*H 

            D0 = DZ/cos0
            DX = D0*sin0

            if DX < L:

                T_headwave = (L-DX)/V1  +  D0/V0
                T = min(T,T_headwave)
        
    else: 
        
        if V0 == V1:
            
            D = np.sqrt(L**2+(Z-ZE)**2)
            T = D/V0

        elif L == 0:

            T = (Z-H)/V0 + (H-ZE)/V1
            
        else:

            B0 = ( (Z-H)/L )**2
            B1 = ( (H-ZE)/L )**2
            A0 = B0 * S / (1-S)
            A1 = B1 / (1-S)

            poly_coefs = [1,-2,1+A1-A0,-2*A1,A1]
            
            roots = np.roots(poly_coefs)
            real_roots = roots[roots.imag == 0].real
            
            X = real_roots[np.logical_and(real_roots >= 0,real_roots<=1)][0]
            
            T = L * ( np.sqrt(B1+X**2)/V1 + np.sqrt(B0+(1-X)**2)/V0 )
        
    return T
#################################################################


#################################################################
def eva_travel_times(Ls,Zs,Ps,ZE,velocity_model):
    
    VP0,VP1,VS0,VS1,H = velocity_model

    DTs_mod = np.empty(len(Ls))        
    for i,(L,Z,P) in enumerate(zip(Ls,Zs,Ps)):
        if P == 1:
            DTs_mod[i] = eva_travel_time(L,Z,ZE,VS0,VS1,H)
        else:
            DTs_mod[i] = eva_travel_time(L,Z,ZE,VP0,VP1,H)
        
    return DTs_mod
#################################################################

# %% [markdown]
# ```{div} full-width
# Before solving the inverse problem of the earthquake localization, let us plot the travel times as function of the hypocentral distance for the cases $z_e=-7$ and $-13$ km (above and below the Conrad discontinuity)
# ```

# %%
fig,axes = plt.subplots(1,3,tight_layout=True,figsize=(10,5))

for ZE in [-7,-13]:

    label = str(-ZE)+" [km]"
    
    Ls = np.linspace(0,100,1000)
    Zs = np.zeros(Ls.shape)
    Ps = np.zeros(Ls.shape)

    Ds1 = np.sqrt(Ls**2+(Zs-ZE)**2)
    Ts1 = eva_travel_times(Ls,Zs,Ps,ZE,velocity_model)

    Ls = 10**np.linspace(0,4,1000)
    
    Ds2 = np.sqrt(Ls**2+(Zs-ZE)**2)
    Ts2 = eva_travel_times(Ls,Zs,Ps,ZE,velocity_model)

    ax = axes[0]
    ax.plot(Ts1,Ds1,label=label)

    axes[1].plot(Ds1/Ts1,Ds1,label=label)
    axes[2].semilogy(Ds2/Ts2,Ds2,label=label)

axes[0].set_ylabel("Hypocentral distance [km]")
axes[0].set_xlabel("Travel time [s]")
axes[1].set_xlabel("Distance / Time [km/s]")        
axes[2].set_xlabel("Distance / Time [km/s]")        

for ax in axes:
    ax.axhline(0,linewidth=0.5)
    ax.legend()

# %% [markdown]
# ```{div} full-width
# As we can see ...
#
# Let us now make ude of the function `eva_travel_times` for compouting the WRSS
# ```

# %%
def eva_wrss(m,data,velocity_model,logy=False):
    
    TE,XE,YE,ZE = m
    Ts,Xs,Ys,Zs,Es,Ps = data
    Ls = np.sqrt( (Xs-XE)**2 + (Ys-YE)**2 )

    Ts_mod = eva_travel_times(Ls,Zs,Ps,ZE,velocity_model) + TE

    WRSS = (((Ts-Ts_mod)/Es)**2).sum()
        
    if logy:
        return WRSS, Ts_mod
    else:
        return WRSS

# %%
wrss = eva_wrss(ingv,data,velocity_model)
print("wrss:",wrss)

# %%
wrss, Ts_mod = eva_wrss(ingv,data,velocity_model,True)

# %%
fig = lab.plot_data(data,ingv,Ts_mod)

# %% [markdown]
# ```{div} full-width
# Let us now consider the starting point that we already use for the homogeneous half-space model and find the minimum of the WRSS
# ```

# %%
fun = lambda m: eva_wrss(m,data,velocity_model)
sol = optimize.minimize(fun,guess,bounds=bounds)

print(sol)

# %%
exts = { "TE":[-0.2,0.2], "XE":[-1,1], "YE":[-1,1], "ZE":[-1,1] }
fig = plot_wrss(sol.x, exts, fun)

# %% [markdown]
# ### Searching for multiple local minima

# %%
def make_guesses(nwalkers,lims):

    spans = np.diff(lims,axis=1)
    print(spans[:,0])
    print(lims[:,0])
    ndim = len(lims)
    guesses = np.random.rand(nwalkers, ndim) * spans[:,0] + lims[:,0]

    return guesses

nwalkers = 50
mlims = np.array([[-5,0],[-20,20],[-20,20],[-20,0]])

guesses = make_guesses(nwalkers,mlims)
print("\nmean =",guesses.mean(axis=0))
print("std  =",guesses.std(axis=0))
print(guesses)

# %%
sols = []
for i,guess in enumerate(guesses):
    sol = optimize.minimize(fun,guess,bounds=bounds)
    print(i,guess,sol.x,sol.fun)
    sols.append(sol)

# %%
delta_max = 1e-3

uniques = []
for i,sol_new in enumerate(sols):
    logy = True
    for j in uniques:
        sol = sols[j]
        delta = np.sqrt(( (sol.x-sol_new.x)**2 ).sum())
        if delta < delta_max:
            logy = False
    if logy: 
        uniques.append(i)
        print("best =",sol.x,"fun =",sol.fun)
        
uniques = np.array(uniques)
print("uniques =",uniques)

js = np.argsort([sols[j].fun for j in uniques])
uniques = uniques[js]
print("sorted uniques =",uniques)

sols = [sols[j] for j in uniques]
for sol in sols:
    fig = plot_wrss(sol.x, exts, fun)

# %% [markdown]
# ### Estimates of the uncercainties

# %%
###########################################################s
def eva_functional(fun,m,N):
    
    wrss = fun(m)
    L = N * np.log(wrss)
    
    return L
###########################################################s

from scipy import linalg

###########################################################s
def make_inverse_symmetric(hess):

    w,o = linalg.eigh(hess)
    inv = (o / w) @ o.T
    return inv
###########################################################s


###########################################################s
def make_hess(functional,mb,steps):

    M = len(mb)
    H = np.empty((M,M))
    f0 = functional(mb)
    
    dm = np.eye(M) * steps
    for i in range(M):
        eps = steps[i]
        f_up = functional(mb+dm[i]) 
        f_dw = functional(mb-dm[i])
        H[i,i] = ( f_up + f_dw - 2*f0 ) / steps[i]**2
        for j in range(i):
            up =  ( functional(mb+dm[i]/2+dm[j]/2) - functional(mb-dm[i]/2+dm[j]/2) ) / steps[i]
            dw =  ( functional(mb+dm[i]/2-dm[j]/2) - functional(mb-dm[i]/2-dm[j]/2) ) / steps[i]
            H[i,j] = (up-dw) / steps[j]
            H[j,i] = H[i,j]
        
    return H
###########################################################

# %%
functional = lambda m: eva_functional(fun,m,N)

steps = np.ones(M)*1e-4

ms = np.empty((len(sols),M))
Ws = np.empty(len(sols))
Ls = np.empty(len(sols))
covs = np.empty((len(sols),M,M))
for i,sol in enumerate(sols):
    m = sol.x
    ms[i] = sol.x
    Ws[i] = sol.fun
    Ls[i] = functional(m)
    H = make_hess(functional,m,steps)
    covs[i] = 2*make_inverse_symmetric(H)
    print(Ws[i])
    print(ms[i])
    print(np.sqrt(np.diag(covs[i])))
DL = Ls[0]-Ls[1]
print(DL)

# %% [markdown]
# <p style="page-break-after:always;"></p>
